# %% [markdown]
# # Import Statements and Load Data

# %%
import pandas as pd
import numpy as np

import sqlite3

from pandasql import sqldf
psdf = lambda x: sqldf(x, globals())

import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
conn = sqlite3.connect('Data/im.db')

query = ''' SELECT *
            FROM movie_basics
            JOIN movie_ratings
            USING(movie_id)
            ;'''

imdb_movies = pd.read_sql(query, conn)

imdb_movies.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
tn_movie_budgets = pd.read_csv('rawData/tn.movie_budgets.csv.gz', compression='gzip')

tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
bom_movie_gross = pd.read_csv('rawData/bom.movie_gross.csv.gz', compression='gzip')

bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# # Transform Data

# %%
def to_float(value):
    """Takes in a string or float. If string, removes up to 3 commas, 1 $ sign, and whitespace, then converts to float."""
    if type(value) == float:
        return value
    else:
        value = value.replace(',', '')
        value = value.replace(',', '')
        value = value.replace(',', '')
        value = value.replace('$', '')
        value = value.strip()
        return float(value)

# %% [markdown]
# #### Transform budget and revenue columns in tn_movie_budgets (to float)

# %%
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].map(to_float)

# %%
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].map(to_float)

# %%
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].map(to_float)

# %% [markdown]
# #### Inspect all dataframes for missing values or unexpected behavior

# %%
imdb_movies.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
imdb_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         73856 non-null  object
#  1   primary_title    73856 non-null  object
#  2   original_title   73856 non-null  object
#  3   start_year       73856 non-null  int64
#  4   runtime_minutes  66236 non-null  float64
#  5   genres           73052 non-null  object
#  6   averagerating    73856 non-null  float64
#  7   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
tn_movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   float64
#  4   domestic_gross     5782 non-null   float64
#  5   worldwide_gross    5782 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 271.2+ KB

# %%
bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom_movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   float64
#  4   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 132.4+ KB

# %% [markdown]
# #### Transform bom_movie_gross foreign_gross values (to float)

# %%
bom_movie_gross['foreign_gross'] = bom_movie_gross['foreign_gross'].map(to_float)

# %% [markdown]
# ### Join all data into one table

# %% [markdown]
# #### Make a field called "movie_year" in all tables, to match records by film title and release year

# %%
imdb_movies['movie_year'] = imdb_movies['primary_title'] + ' ' + imdb_movies['start_year'].map(lambda x: str(x))

# %%
tn_movie_budgets['movie_year'] = tn_movie_budgets['movie'] + ' ' + tn_movie_budgets['release_date'].map(lambda x: x[-4:])

# %%
bom_movie_gross['movie_year'] = bom_movie_gross['title'] + ' ' + bom_movie_gross['year'].map(lambda x: str(x))

# %% [markdown]
# #### Use pandasql to join the tables on movie_year, and perform an inner join

# %%
query = ''' SELECT b.title, t.production_budget, t.domestic_gross, b.foreign_gross, t.worldwide_gross, i.runtime_minutes,
                    i.genres, b.studio, t.release_date, i.start_year, i.movie_id
            FROM tn_movie_budgets as t
            INNER JOIN imdb_movies as i
            USING(movie_year)
            INNER JOIN bom_movie_gross as b
            USING(movie_year)
            ;
            '''

movie_data = psdf(query)

# %% [markdown]
# #### Import directors & writers from imdb database for movies in movie_data

# %%
query = f''' SELECT d.movie_id, d.person_id, p.primary_name
            FROM directors as d
            JOIN persons as p
            USING(person_id)
            WHERE movie_id IN {tuple(preliminary_movie_data['movie_id'].values)}
            ;
            '''
directors = pd.read_sql(query, conn)

directors.head()
# Out:
#     movie_id  person_id        primary_name
# 0  tt1126618  nm0585011       Roger Michell
# 1  tt1336608  nm0788202       Adam Shankman
# 2  tt1336608  nm0788202       Adam Shankman
# 3  tt1336608  nm0788202       Adam Shankman
# 4  tt1341167  nm0606439  Christopher Morris

# %% [markdown]
# Some movie_id and person_id info is duplicated. Drop duplicates.

# %%
directors.drop_duplicates(inplace=True)

# %%
query = f''' SELECT w.movie_id, w.person_id, p.primary_name
            FROM writers as w
            JOIN persons as p
            USING(person_id)
            WHERE movie_id IN {tuple(preliminary_movie_data['movie_id'].values)}
            ;
            '''
writers = pd.read_sql(query, conn)

writers.head()
# Out:
#     movie_id  person_id         primary_name
# 0  tt1126618  nm0112459  Aline Brosh McKenna
# 1  tt1336608  nm0857620       Justin Theroux
# 2  tt1336608  nm0195476      Chris D'Arienzo
# 3  tt1336608  nm1615610           Allan Loeb
# 4  tt1341167  nm0606439   Christopher Morris

# %%
writers.drop_duplicates(inplace=True)

# %%
query = ''' SELECT m.title, m.production_budget, m.domestic_gross, m.foreign_gross, m.worldwide_gross, m.runtime_minutes,
                    m.genres, m.studio,
                    d.primary_name AS director,
                    w.primary_name AS writer,
                    m.release_date, m.start_year,
                    d.person_id AS director_id, w.person_id AS writer_id,
                    m.movie_id
            FROM preliminary_movie_data as m
            JOIN directors as d
            USING(movie_id)
            JOIN writers as w
            USING(movie_id)
            ;
            '''
psdf(query)

# %% [markdown]
# ### Deal with Missing Values

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1043 entries, 0 to 1042
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1043 non-null   object
#  1   production_budget  1043 non-null   float64
#  2   domestic_gross     1043 non-null   float64
#  3   foreign_gross      940 non-null    float64
#  4   worldwide_gross    1043 non-null   float64
#  5   runtime_minutes    1040 non-null   float64
#  6   genres             1042 non-null   object
#  7   studio             1043 non-null   object
#  8   release_date       1043 non-null   object
#  9   start_year         1043 non-null   int64
#  10  movie_id           1043 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 89.8+ KB

# %% [markdown]
# #### Drop 3 records which are missing genres and / or runtime.

# %%
movie_data.dropna(subset=['genres', 'runtime_minutes'], inplace=True)

# %% [markdown]
# #### Inspect missing foreign_gross values.

# %% [markdown]
# The cell below was rerun after filling missing values in the foreign gross column. There are *still* 919 records for which the foreign_gross and domestic_gross do NOT add up to the worldwide_gross. The foreign_gross column comes from the Box Office Mojo dataset, whereas the domestic_gross and worldwide_gross came from The Numbers dataset. This could explain the discrepancy, though I am curious as to why they have different numbers. Is one of them more up to date? Does one of them include only box-office revenue, whereas the other includes DVD sales, selling rights to streaming services, and merchandise related to the film?

# %%
# How many records such that domestic gross + foreign gross NOT = worldwide gross?
len(movie_data.loc[movie_data['domestic_gross'] + movie_data['foreign_gross'] != movie_data['worldwide_gross']])
# Out:
# 919

# %%
movie_data['foreign_gross'].isna().value_counts()
# Out:
# False    937
# True     103
# Name: foreign_gross, dtype: int64

# %% [markdown]
# #### Fill missing foreign_gross values with the difference between the worldwide gross and the domestic gross.

# %%
computed_foreign_gross = movie_data['worldwide_gross'] - movie_data['domestic_gross']

# %%
movie_data['foreign_gross'].fillna(value=computed_foreign_gross, inplace=True)

# %% [markdown]
# ### Add necessary fields to movie_data for analysis

# %%
movie_data['roi'] = (movie_data['worldwide_gross'] - movie_data['production_budget']) / movie_data['production_budget']

# %%
movie_data.head()
# Out:
#                                          title  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides        410600000.0
# 1                      Avengers: Age of Ultron        330600000.0
# 2                       Avengers: Infinity War        300000000.0
# 3                               Justice League        300000000.0
# 4                                      Spectre        300000000.0
#
#    domestic_gross  foreign_gross  worldwide_gross  runtime_minutes  \
# 0     241063875.0    804600000.0     1.045664e+09            136.0
# 1     459005868.0    946400000.0     1.403014e+09            141.0
# 2     678815482.0         1369.5     2.048134e+09            149.0
# 3     229024295.0    428900000.0     6.559452e+08            120.0
# 4     200074175.0    680600000.0     8.796209e+08            148.0
#
#                       genres studio  release_date  start_year   movie_id  \
# 0   Action,Adventure,Fantasy     BV  May 20, 2011        2011  tt1298650
# 1    Action,Adventure,Sci-Fi     BV   May 1, 2015        2015  tt2395427
# 2    Action,Adventure,Sci-Fi     BV  Apr 27, 2018        2018  tt4154756
# 3   Action,Adventure,Fantasy     WB  Nov 17, 2017        2017  tt0974015
# 4  Action,Adventure,Thriller   Sony   Nov 6, 2015        2015  tt2379713
#
#         roi
# 0  1.546673
# 1  3.243841
# 2  5.827114
# 3  1.186484
# 4  1.932070

# %% [markdown]
# # Begin Genre Analysis:
# ### Which genre combinations result in the highest average ROI? What is the standard deviation of the ROI within that group?

# %% [markdown]
# Group the data by genre groups. Find the genre group with the highest average ROI. Also examine the standard deviation of the ROI in that genre group.

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1040 entries, 0 to 1042
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1040 non-null   object
#  1   production_budget  1040 non-null   float64
#  2   domestic_gross     1040 non-null   float64
#  3   foreign_gross      1040 non-null   float64
#  4   worldwide_gross    1040 non-null   float64
#  5   runtime_minutes    1040 non-null   float64
#  6   genres             1040 non-null   object
#  7   studio             1040 non-null   object
#  8   release_date       1040 non-null   object
#  9   start_year         1040 non-null   int64
#  10  movie_id           1040 non-null   object
#  11  roi                1040 non-null   float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 105.6+ KB

# %% [markdown]
# Find the genre combinations with the highest average return on investment.

# %%
movie_data.groupby('genres').mean()['roi'].sort_values(ascending=False)[:10]
# Out:
# genres
# Horror,Mystery,Thriller    33.874268
# Horror                     28.206820
# Comedy,Documentary         11.930902
# Biography,Drama,Fantasy    11.679440
# Drama,Horror,Mystery       10.851890
# Drama,Horror,Thriller      10.151841
# Comedy,Fantasy              9.463138
# Action,Mystery,Sci-Fi       9.244702
# Drama,Horror,Sci-Fi         9.227946
# Adventure,Drama,Fantasy     8.630940
# Name: roi, dtype: float64

# %% [markdown]
# How many movies of that genre combination are in our dataset?

# %%
movie_data.groupby('genres').count()['title'].loc[list(movie_data.groupby('genres').mean()['roi'].sort_values(ascending=False)[:10].index)]
# Out:
# genres
# Horror,Mystery,Thriller    24
# Horror                      6
# Comedy,Documentary          1
# Biography,Drama,Fantasy     1
# Drama,Horror,Mystery        7
# Drama,Horror,Thriller       5
# Comedy,Fantasy              4
# Action,Mystery,Sci-Fi       1
# Drama,Horror,Sci-Fi         2
# Adventure,Drama,Fantasy     4
# Name: title, dtype: int64

# %% [markdown]
# What are the largest sample sizes we have for each genre combination?

# %%
movie_data.groupby('genres').count()['title'].sort_values(ascending=False)[:70]
# Out:
# genres
# Adventure,Animation,Comedy    60
# Comedy,Drama,Romance          43
# Action,Adventure,Sci-Fi       42
# Comedy                        36
# Comedy,Drama                  33
#                               ..
# Action,Comedy,Sci-Fi           4
# Action,Comedy,Romance          4
# Drama,Romance,Sci-Fi           4
# Crime,Thriller                 4
# Crime,Drama,Horror             4
# Name: title, Length: 70, dtype: int64

# %% [markdown]
# Adjust previous grouping and ordering, by limiting the data to only those genre combinations with at least 30 films in the data set.

# %%
query = ''' SELECT genres, COUNT(title) AS num_movies, AVG(roi) AS avg_roi
            FROM movie_data
            GROUP BY genres
            HAVING COUNT(title) >= 10
            ORDER BY AVG(roi) DESC
            LIMIT 10
            ;
            '''

psdf(query)
# Out:
#                        genres  num_movies    avg_roi
# 0     Horror,Mystery,Thriller          24  33.874268
# 1             Horror,Thriller          16   6.307949
# 2     Action,Adventure,Comedy          15   3.639460
# 3               Drama,Romance          26   3.365954
# 4                       Drama          30   3.286955
# 5  Adventure,Animation,Comedy          60   3.241836
# 6     Biography,Drama,History          18   3.004742
# 7     Action,Adventure,Sci-Fi          42   2.963922
# 8      Biography,Comedy,Drama          15   2.958810
# 9             Biography,Drama          13   2.921237

# %% [markdown]
# The average return on investment for these "top 10" films is much lower than those in the original list, without controlling for sample size. Let's investigate 'Horror, Mystery, Thriller' from the original top 10 list, which is getting *close* to the min sample size of 30, along with the top 10 generated by controlling for sample size.

# %% [markdown]
# # Get more data! Bring in the TMDB 5000 dataset from Kaggle
#
# Kaggle dataset: https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata?resource=download&select=tmdb_5000_movies.csv

# %%
kaggle_tmdb_5000 = pd.read_csv('rawData/tmdb_5000_movies.csv.zip')

# %%
kaggle_tmdb_5000.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
kaggle_tmdb_5000['genres'].loc[0].split(',')
# Out:
# ['[{"id": 28',
#  ' "name": "Action"}',
#  ' {"id": 12',
#  ' "name": "Adventure"}',
#  ' {"id": 14',
#  ' "name": "Fantasy"}',
#  ' {"id": 878',
#  ' "name": "Science Fiction"}]']

# %% [markdown]
# release_date column has mostly strings, but one float.

# %%
kaggle_tmdb_5000['release_date'].map(lambda x: type(x)).value_counts()
# Out:
# <class 'str'>      4802
# <class 'float'>       1
# Name: release_date, dtype: int64

# %% [markdown]
# Change release_date column to all be string type.

# %%
kaggle_tmdb_5000['release_date'] = kaggle_tmdb_5000['release_date'].astype('string')

# %% [markdown]
# Make the movie_year column needed to match kaggle data with preexisting data set.

# %%
kaggle_tmdb_5000['movie_year'] = kaggle_tmdb_5000['original_title'] + ' ' +\
                                kaggle_tmdb_5000['release_date'].map(lambda x: str(x)[:4])

# %% [markdown]
# Combine all the data!!

# %%
query = ''' SELECT t.release_date, t.movie, t.production_budget, t.domestic_gross, t.worldwide_gross,
                    i.primary_title, i.start_year, i.runtime_minutes, i.genres AS imdb_genres,
                    k.genres AS tmdb_genres, k.keywords, k.original_title, k.overview, k.production_companies,
                    k.release_date AS tmdb_release_date, k.runtime AS tmdb_runtime
            FROM tn_movie_budgets as t
            LEFT JOIN imdb_movies as i
            ON i.movie_year = t.movie_year
            LEFT JOIN kaggle_tmdb_5000 as k
            ON i.movie_year = k.movie_year
            WHERE (k.budget IS NOT NULL) | (t.production_budget IS NOT NULL)
            ;
            '''

all_movies = psdf(query)

# %%
len(all_movies)
# Out:
# 5818

# %%
all_movies.head(3)
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                         None         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# 2                                 Dark Phoenix      2019.0            113.0
#
#                 imdb_genres  \
# 0                      None
# 1  Action,Adventure,Fantasy
# 2   Action,Adventure,Sci-Fi
#
#                                          tmdb_genres  \
# 0                                               None
# 1  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 2                                               None
#
#                                             keywords  \
# 0                                               None
# 1  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
# 2                                               None
#
#                                 original_title  \
# 0                                         None
# 1  Pirates of the Caribbean: On Stranger Tides
# 2                                         None
#
#                                             overview  \
# 0                                               None
# 1  Captain Jack Sparrow crosses paths with a woma...
# 2                                               None
#
#                                 production_companies tmdb_release_date  \
# 0                                               None              None
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...        2011-05-14
# 2                                               None              None
#
#    tmdb_runtime
# 0           NaN
# 1         136.0
# 2           NaN

# %% [markdown]
# #### Deal with missing values from budget or production_budget

# %% [markdown]
# If a value exists for one, but not the other (referring to budget & production_budget), fill that value.

# %%
all_movies['budget'].isna().value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'budget'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-15dcc8f4a0b5> in <module>
# ----> 1 all_movies['budget'].isna().value_counts()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'budget'

# %%
all_movies['production_budget'].fillna(all_movies['budget'])

# %%
all_movies['production_budget'] = all_movies['production_budget'].fillna(all_movies['budget'])

# %%
all_movies['budget'] = all_movies['budget'].fillna(all_movies['production_budget'])

# %% [markdown]
# Where are the production_budget and budget values significantly different (by more than 1%)?

# %%
all_movies.loc[ ((all_movies['production_budget'] - all_movies['budget']) / all_movies['production_budget'] > 0.01)\
              | ((all_movies['production_budget'] - all_movies['budget']) / all_movies['budget'] > 0.01) ]
# Out:
#       id  release_date                                        movie  \
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 9     10   Nov 6, 2015                                      Spectre
# 10    11  Jul 20, 2012                        The Dark Knight Rises
# 12    13   Jul 2, 2013                              The Lone Ranger
# ...   ..           ...                                          ...
# 5764  29  Jun 21, 2013                        This Is Martin Bonner
# 5767  32  Feb 11, 2011                               Raymond Did It
# 5770  35  Oct 25, 2013            Her Cry: La Llorona Investigation
# 5787  52   Dec 1, 2015                                  Dutch Kills
# 5797  62  Dec 31, 2014                         Stories of Our Lives
#
#       production_budget  domestic_gross  worldwide_gross  \
# 1           410600000.0     241063875.0     1.045664e+09
# 3           330600000.0     459005868.0     1.403014e+09
# 9           300000000.0     200074175.0     8.796209e+08
# 10          275000000.0     448139099.0     1.084439e+09
# 12          275000000.0      89302115.0     2.600021e+08
# ...                 ...             ...              ...
# 5764            42000.0             0.0     0.000000e+00
# 5767            40000.0          3632.0     3.632000e+03
# 5770            35000.0             0.0     0.000000e+00
# 5787            25000.0             0.0     0.000000e+00
# 5797            15000.0             0.0     0.000000e+00
#
#                                             movie_year   movie_id  \
# 1     Pirates of the Caribbean: On Stranger Tides 2011  tt1298650
# 3                         Avengers: Age of Ultron 2015  tt2395427
# 9                                         Spectre 2015  tt2379713
# 10                          The Dark Knight Rises 2012  tt1345836
# 12                                The Lone Ranger 2013  tt1210819
# ...                                                ...        ...
# 5764                        This Is Martin Bonner 2013  tt1798291
# 5767                               Raymond Did It 2011  tt1716760
# 5770            Her Cry: La Llorona Investigation 2013  tt2469216
# 5787                                  Dutch Kills 2015  tt2759066
# 5797                         Stories of Our Lives 2014  tt3973612
#
#                                     primary_title  \
# 1     Pirates of the Caribbean: On Stranger Tides
# 3                         Avengers: Age of Ultron
# 9                                         Spectre
# 10                          The Dark Knight Rises
# 12                                The Lone Ranger
# ...                                           ...
# 5764                        This Is Martin Bonner
# 5767                               Raymond Did It
# 5770            Her Cry: La Llorona Investigation
# 5787                                  Dutch Kills
# 5797                         Stories of Our Lives
#
#                                    original_title  ...  release_date  \
# 1     Pirates of the Caribbean: On Stranger Tides  ...    2011-05-14
# 3                         Avengers: Age of Ultron  ...    2015-04-22
# 9                                         Spectre  ...    2015-10-26
# 10                          The Dark Knight Rises  ...    2012-07-16
# 12                                The Lone Ranger  ...    2013-07-03
# ...                                           ...  ...           ...
# 5764                        This Is Martin Bonner  ...    2013-06-28
# 5767                               Raymond Did It  ...    2011-03-27
# 5770            Her Cry: La Llorona Investigation  ...    2013-04-19
# 5787                                  Dutch Kills  ...    2015-10-02
# 5797                         Stories of Our Lives  ...    2014-09-05
#
#            revenue runtime                                   spoken_languages  \
# 1     1.045714e+09   136.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 3     1.405404e+09   141.0           [{"iso_639_1": "en", "name": "English"}]
# 9     8.806746e+08   148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 10    1.084939e+09   165.0           [{"iso_639_1": "en", "name": "English"}]
# 12    8.928991e+07   149.0           [{"iso_639_1": "en", "name": "English"}]
# ...            ...     ...                                                ...
# 5764  0.000000e+00    83.0           [{"iso_639_1": "en", "name": "English"}]
# 5767  0.000000e+00    83.0           [{"iso_639_1": "en", "name": "English"}]
# 5770  0.000000e+00    89.0                                                 []
# 5787  0.000000e+00    90.0                                                 []
# 5797  0.000000e+00    60.0  [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...
#
#         status                                            tagline  \
# 1     Released                        Live Forever Or Die Trying.
# 3     Released                                A New Age Has Come.
# 9     Released                              A Plan No One Escapes
# 10    Released                                    The Legend Ends
# 12    Released                            Never Take Off the Mask
# ...        ...                                                ...
# 5764  Released  Sometimes You Have to Lose Your Life in Order ...
# 5767  Released                             Mom's Pretty Mad At Me
# 5770  Released                                               None
# 5787  Released                                               None
# 5797  Released                                               None
#
#                                             title vote_average vote_count  \
# 1     Pirates of the Caribbean: On Stranger Tides          6.4     4948.0
# 3                         Avengers: Age of Ultron          7.3     6767.0
# 9                                         Spectre          6.3     4466.0
# 10                          The Dark Knight Rises          7.6     9106.0
# 12                                The Lone Ranger          5.9     2311.0
# ...                                           ...          ...        ...
# 5764                        This Is Martin Bonner          6.6        4.0
# 5767                               Raymond Did It          3.2        8.0
# 5770            Her Cry: La Llorona Investigation          0.0        0.0
# 5787                                  Dutch Kills          0.0        0.0
# 5797                         Stories of Our Lives          0.0        0.0
#
#                                             movie_year
# 1     Pirates of the Caribbean: On Stranger Tides 2011
# 3                         Avengers: Age of Ultron 2015
# 9                                         Spectre 2015
# 10                          The Dark Knight Rises 2012
# 12                                The Lone Ranger 2013
# ...                                                ...
# 5764                        This Is Martin Bonner 2013
# 5767                               Raymond Did It 2011
# 5770            Her Cry: La Llorona Investigation 2013
# 5787                                  Dutch Kills 2015
# 5797                         Stories of Our Lives 2014
#
# [239 rows x 37 columns]

# %% [markdown]
# The number 0 is a placeholder for null in both the budget and production_budget columns!

# %%
all_movies.budget.value_counts()
# Out:
# 0.0            128
# 20000000.0      43
# 40000000.0      35
# 30000000.0      31
# 35000000.0      28
#               ...
# 93000000.0       1
# 1987650.0        1
# 115000000.0      1
# 144000000.0      1
# 76000000.0       1
# Name: budget, Length: 185, dtype: int64

# %%
all_movies.production_budget.value_counts()
# Out:
# 20000000.0     233
# 10000000.0     216
# 30000000.0     179
# 15000000.0     173
# 25000000.0     171
#               ...
# 91000000.0       1
# 916000.0         1
# 5100000.0        1
# 30250000.0       1
# 151000000.0      1
# Name: production_budget, Length: 509, dtype: int64

# %% [markdown]
# In this case, the production_budget column has no null values, and no placeholder 0s, so I will use production_budget and drop budget.

# %%
all_movies.drop(axis=1, labels='budget', inplace=True)

# %%
len(all_movies)
# Out:
# 5818

# %%
all_movies.drop(labels=['id', 'movie_id', 'averagerating', 'numvotes', 'homepage', 'id', 'original_language', 'popularity',\
                        'status', 'vote_average', 'vote_count'], inplace=True, axis=1)

# %%
all_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5818 entries, 0 to 5817
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   release_date          5818 non-null   object
#  1   movie                 5818 non-null   object
#  2   production_budget     5818 non-null   float64
#  3   domestic_gross        5818 non-null   float64
#  4   worldwide_gross       5818 non-null   float64
#  5   movie_year            5818 non-null   object
#  6   primary_title         1498 non-null   object
#  7   original_title        1498 non-null   object
#  8   start_year            1498 non-null   float64
#  9   runtime_minutes       1490 non-null   float64
#  10  genres                1496 non-null   object
#  11  movie_year            1498 non-null   object
#  12  genres                977 non-null    object
#  13  keywords              977 non-null    object
#  14  original_title        977 non-null    object
#  15  overview              976 non-null    object
#  16  production_companies  977 non-null    object
#  17  production_countries  977 non-null    object
#  18  release_date          977 non-null    object
#  19  revenue               977 non-null    float64
#  20  runtime               977 non-null    float64
#  21  spoken_languages      977 non-null    object
#  22  tagline               858 non-null    object
#  23  title                 977 non-null    object
#  24  movie_year            977 non-null    object
# dtypes: float64(7), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Create roi column for all_movies

# %%
all_movies['roi'] = (all_movies['worldwide_gross'] - all_movies['production_budget']) / all_movies['production_budget']

# %%
all_movies[ all_movies['runtime_minutes'].isna() & all_movies['tmdb_runtime'].isna() ]
# Out:
#       release_date                                       movie  \
# 0     Dec 18, 2009                                      Avatar
# 4     Dec 15, 2017           Star Wars Ep. VIII: The Last Jedi
# 5     Dec 18, 2015        Star Wars Ep. VII: The Force Awakens
# 7     May 24, 2007  Pirates of the Caribbean: At Worldâs End
# 15     May 4, 2007                                Spider-Man 3
# ...            ...                                         ...
# 5813  Dec 31, 2018                                      Red 11
# 5814   Apr 2, 1999                                   Following
# 5815  Jul 13, 2005               Return to the Land of Wonders
# 5816  Sep 29, 2015                        A Plague So Pleasant
# 5817   Aug 5, 2005                           My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross primary_title  \
# 0           425000000.0     760507625.0     2.776345e+09          None
# 4           317000000.0     620181382.0     1.316722e+09          None
# 5           306000000.0     936662225.0     2.053311e+09          None
# 7           300000000.0     309420425.0     9.634204e+08          None
# 15          258000000.0     336530303.0     8.948602e+08          None
# ...                 ...             ...              ...           ...
# 5813             7000.0             0.0     0.000000e+00          None
# 5814             6000.0         48482.0     2.404950e+05          None
# 5815             5000.0          1338.0     1.338000e+03          None
# 5816             1400.0             0.0     0.000000e+00          None
# 5817             1100.0        181041.0     1.810410e+05          None
#
#       start_year  runtime_minutes imdb_genres tmdb_genres keywords  \
# 0            NaN              NaN        None        None     None
# 4            NaN              NaN        None        None     None
# 5            NaN              NaN        None        None     None
# 7            NaN              NaN        None        None     None
# 15           NaN              NaN        None        None     None
# ...          ...              ...         ...         ...      ...
# 5813         NaN              NaN        None        None     None
# 5814         NaN              NaN        None        None     None
# 5815         NaN              NaN        None        None     None
# 5816         NaN              NaN        None        None     None
# 5817         NaN              NaN        None        None     None
#
#      original_title overview production_companies tmdb_release_date  \
# 0              None     None                 None              None
# 4              None     None                 None              None
# 5              None     None                 None              None
# 7              None     None                 None              None
# 15             None     None                 None              None
# ...             ...      ...                  ...               ...
# 5813           None     None                 None              None
# 5814           None     None                 None              None
# 5815           None     None                 None              None
# 5816           None     None                 None              None
# 5817           None     None                 None              None
#
#       tmdb_runtime         roi
# 0              NaN    5.532577
# 4              NaN    3.153696
# 5              NaN    5.710167
# 7              NaN    2.211401
# 15             NaN    2.468451
# ...            ...         ...
# 5813           NaN   -1.000000
# 5814           NaN   39.082500
# 5815           NaN   -0.732400
# 5816           NaN   -1.000000
# 5817           NaN  163.582727
#
# [4324 rows x 17 columns]

# %%
all_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5818 entries, 0 to 5817
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   release_date          5818 non-null   object
#  1   movie                 5818 non-null   object
#  2   production_budget     5818 non-null   float64
#  3   domestic_gross        5818 non-null   float64
#  4   worldwide_gross       5818 non-null   float64
#  5   primary_title         1498 non-null   object
#  6   start_year            1498 non-null   float64
#  7   runtime_minutes       1490 non-null   float64
#  8   imdb_genres           1496 non-null   object
#  9   tmdb_genres           977 non-null    object
#  10  keywords              977 non-null    object
#  11  original_title        977 non-null    object
#  12  overview              976 non-null    object
#  13  production_companies  977 non-null    object
#  14  tmdb_release_date     977 non-null    object
#  15  tmdb_runtime          977 non-null    float64
#  16  roi                   5818 non-null   float64
# dtypes: float64(7), object(10)
# memory usage: 772.8+ KB

# %%
all_movies[ ~all_movies['imdb_genres'].isna() & all_movies['tmdb_genres'].isna() ]
# Out:
#       release_date                    movie  production_budget  \
# 2      Jun 7, 2019             Dark Phoenix        350000000.0
# 6     Apr 27, 2018   Avengers: Infinity War        300000000.0
# 8     Nov 17, 2017           Justice League        300000000.0
# 11    May 25, 2018  Solo: A Star Wars Story        275000000.0
# 22    Apr 14, 2017  The Fate of the Furious        250000000.0
# ...            ...                      ...                ...
# 5761  Dec 31, 2014     The Image Revolution            50000.0
# 5768  Mar 31, 2012          Foreign Letters            40000.0
# 5780  Jan 27, 2017                    Emily            27000.0
# 5784   Sep 1, 2015                   Exeter            25000.0
# 5794  Nov 25, 2011               The Ridges            17300.0
#
#       domestic_gross  worldwide_gross            primary_title  start_year  \
# 2         42762350.0     1.497624e+08             Dark Phoenix      2019.0
# 6        678815482.0     2.048134e+09   Avengers: Infinity War      2018.0
# 8        229024295.0     6.559452e+08           Justice League      2017.0
# 11       213767512.0     3.931513e+08  Solo: A Star Wars Story      2018.0
# 22       225764765.0     1.234846e+09  The Fate of the Furious      2017.0
# ...              ...              ...                      ...         ...
# 5761             0.0     0.000000e+00     The Image Revolution      2014.0
# 5768             0.0     0.000000e+00          Foreign Letters      2012.0
# 5780          3547.0     3.547000e+03                    Emily      2017.0
# 5784             0.0     4.897920e+05                   Exeter      2015.0
# 5794             0.0     0.000000e+00               The Ridges      2011.0
#
#       runtime_minutes               imdb_genres tmdb_genres keywords  \
# 2               113.0   Action,Adventure,Sci-Fi        None     None
# 6               149.0   Action,Adventure,Sci-Fi        None     None
# 8               120.0  Action,Adventure,Fantasy        None     None
# 11              135.0  Action,Adventure,Fantasy        None     None
# 22              136.0     Action,Crime,Thriller        None     None
# ...               ...                       ...         ...      ...
# 5761             81.0     Biography,Documentary        None     None
# 5768             99.0              Comedy,Drama        None     None
# 5780             83.0                     Drama        None     None
# 5784             91.0   Horror,Mystery,Thriller        None     None
# 5794             89.0     Drama,Horror,Thriller        None     None
#
#      original_title overview production_companies tmdb_release_date  \
# 2              None     None                 None              None
# 6              None     None                 None              None
# 8              None     None                 None              None
# 11             None     None                 None              None
# 22             None     None                 None              None
# ...             ...      ...                  ...               ...
# 5761           None     None                 None              None
# 5768           None     None                 None              None
# 5780           None     None                 None              None
# 5784           None     None                 None              None
# 5794           None     None                 None              None
#
#       tmdb_runtime        roi
# 2              NaN  -0.572108
# 6              NaN   5.827114
# 8              NaN   1.186484
# 11             NaN   0.429641
# 22             NaN   3.939385
# ...            ...        ...
# 5761           NaN  -1.000000
# 5768           NaN  -1.000000
# 5780           NaN  -0.868630
# 5784           NaN  18.591680
# 5794           NaN  -1.000000
#
# [520 rows x 17 columns]

# %% [markdown]
# There is one record for which tmdb has a genre, and imdb doesn't. Hard code the tmdb genre into the imdb column for that record. Then drop the tmdb_genres column, and rename the imdb_genres column as genres.

# %%
all_movies.loc[1278, 'imdb_genres'] = 'Action'

# %%
all_movies.drop(axis=1, labels='tmdb_genres', inplace=True)

# %%
all_movies.rename(columns={'imdb_genres':'genres'}, inplace=True)

# %%
all_movies.loc[ all_movies['genres'].isna() ]
# Out:
#       release_date                                       movie  \
# 0     Dec 18, 2009                                      Avatar
# 4     Dec 15, 2017           Star Wars Ep. VIII: The Last Jedi
# 5     Dec 18, 2015        Star Wars Ep. VII: The Force Awakens
# 7     May 24, 2007  Pirates of the Caribbean: At Worldâs End
# 15     May 4, 2007                                Spider-Man 3
# ...            ...                                         ...
# 5813  Dec 31, 2018                                      Red 11
# 5814   Apr 2, 1999                                   Following
# 5815  Jul 13, 2005               Return to the Land of Wonders
# 5816  Sep 29, 2015                        A Plague So Pleasant
# 5817   Aug 5, 2005                           My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross primary_title  \
# 0           425000000.0     760507625.0     2.776345e+09          None
# 4           317000000.0     620181382.0     1.316722e+09          None
# 5           306000000.0     936662225.0     2.053311e+09          None
# 7           300000000.0     309420425.0     9.634204e+08          None
# 15          258000000.0     336530303.0     8.948602e+08          None
# ...                 ...             ...              ...           ...
# 5813             7000.0             0.0     0.000000e+00          None
# 5814             6000.0         48482.0     2.404950e+05          None
# 5815             5000.0          1338.0     1.338000e+03          None
# 5816             1400.0             0.0     0.000000e+00          None
# 5817             1100.0        181041.0     1.810410e+05          None
#
#       start_year  runtime_minutes genres keywords original_title overview  \
# 0            NaN              NaN   None     None           None     None
# 4            NaN              NaN   None     None           None     None
# 5            NaN              NaN   None     None           None     None
# 7            NaN              NaN   None     None           None     None
# 15           NaN              NaN   None     None           None     None
# ...          ...              ...    ...      ...            ...      ...
# 5813         NaN              NaN   None     None           None     None
# 5814         NaN              NaN   None     None           None     None
# 5815         NaN              NaN   None     None           None     None
# 5816         NaN              NaN   None     None           None     None
# 5817         NaN              NaN   None     None           None     None
#
#      production_companies tmdb_release_date  tmdb_runtime         roi
# 0                    None              None           NaN    5.532577
# 4                    None              None           NaN    3.153696
# 5                    None              None           NaN    5.710167
# 7                    None              None           NaN    2.211401
# 15                   None              None           NaN    2.468451
# ...                   ...               ...           ...         ...
# 5813                 None              None           NaN   -1.000000
# 5814                 None              None           NaN   39.082500
# 5815                 None              None           NaN   -0.732400
# 5816                 None              None           NaN   -1.000000
# 5817                 None              None           NaN  163.582727
#
# [4321 rows x 16 columns]

# %% [markdown]
# # Return to genre analysis
# Now that we have more data, let's see how many genre combinations have at least 30 films in the sample.

# %%
all_movies.groupby('genres').count()['movie'].sort_values(ascending=False)
# Out:
# genres
# Adventure,Animation,Comedy    67
# Drama                         57
# Comedy                        56
# Action,Adventure,Sci-Fi       52
# Comedy,Drama,Romance          51
#                               ..
# Comedy,Horror,Mystery          1
# Comedy,Horror,Sci-Fi           1
# Comedy,Music,War               1
# Comedy,Mystery,Sci-Fi          1
# Comedy,Crime,Romance           1
# Name: movie, Length: 229, dtype: int64

# %%
query = ''' SELECT genres, COUNT(*) AS num_movies, AVG(roi) AS avg_roi
            FROM all_movies
            GROUP BY genres
            HAVING COUNT(*) >= 30
            ORDER BY AVG(roi) DESC
            ;
            '''
psdf(query)
# Out:
#                         genres  num_movies    avg_roi
# 0      Horror,Mystery,Thriller          31  27.524288
# 1                         None        4321   4.171000
# 2                Drama,Romance          34   3.823069
# 3   Adventure,Animation,Comedy          67   2.983651
# 4      Action,Adventure,Sci-Fi          52   2.734575
# 5         Comedy,Drama,Romance          51   2.188463
# 6                        Drama          57   2.173775
# 7               Comedy,Romance          41   2.173336
# 8                 Comedy,Drama          48   2.128621
# 9     Action,Adventure,Fantasy          31   1.494635
# 10         Action,Comedy,Crime          31   1.469341
# 11                      Comedy          56   1.342571
# 12          Action,Crime,Drama          39   1.006888

# %% [markdown]
# I want to see a boxplot of the return on investment for movies in the "Horror, Mystery, Thriller" genre in this dataset.

# %%
hmt_roi = all_movies.loc[ all_movies['genres'] == 'Horror,Mystery,Thriller' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(hmt_roi);

# %%
query = ''' SELECT primary_title, roi
            FROM all_movies
            WHERE roi > 400
            ;
            '''
psdf(query)
# Out:
#   primary_title          roi
# 0          None   412.833333
# 1          None   430.517853
# 2          None   497.750000
# 3   The Gallows   415.564740
# 4          None  1799.000000

# %%
fig, ax = plt.subplots()

ax.boxplot(hmt_roi, showfliers=False);

# %%
dr_roi = all_movies.loc[ all_movies['genres'] == 'Drama,Romance' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(dr_roi);

# %%
aac_roi = all_movies.loc[ all_movies['genres'] == 'Adventure,Animation,Comedy' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(aac_roi);

# %%
aas_roi = all_movies.loc[ all_movies['genres'] == 'Action,Adventure,Sci-Fi' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(aas_roi);

# %% [markdown]
# # Try scraping google search results for genre

# %% [markdown]
# 1. Iterate through titles of movies which don't currently have a genre or genres listed. (i.e. all_movies.movie.values for which all_movies.genres.isna() )
# 2. Split the movie title on spaces, then concatenate separated by +s. Then concatenate with string 'www.google.com/search?q=' on the left, and '+film+' + str(year in which film was released.)
# 3. Pass this URL to beautiful soup! I am going to pass a particular URL to beautiful soup below to be sure that I can extract the genre from the page successfully, before working to construct the loop to scrape many sites.

# %%
from bs4 import BeautifulSoup
import requests

# %%
# html_page = requests.get('https://www.google.com/search?q=avatar+2009+film')
html_page = requests.get('https://www.google.com/search?q=avatar+2009+film&rlz=1C1CHBD_enUS895US895&oq=avat&aqs=chrome.0.69i59j69i57j46i67i433j46i67i131i433j46i67i433j69i60l3.1108j0j7&sourceid=chrome&ie=UTF-8')
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>avatar 2009 film - Google Search</title><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# var a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=function(g){g&&g.target.setAttribute("data-iml",Date.now())};document.documentElement.addEventListener("load",h,!0);google.rglh=function(){document.documentElement.removeEventListener("load",h,!0)};}).call(this);(function(){window._skwEvts=[];})();(function(){window.google.erd={jsr:1,bv:1612,de:true};})();(function(){var sdo=false;var mei=10;
# var f=this||self;var g,h=null!=(g=f.mei)?g:1,m,n=null!=(m=f.sdo)?m:!0,p=0,q,r=google.erd,u=r.jsr;google.ml=function(a,b,d,k,c){c=void 0===c?2:c;b&&(q=a&&a.message);if(google.dl)return google.dl(a,c,d),null;if(0>u){window.console&&console.error(a,d);if(-2===u)throw a;b=!1}else b=!a||!a.message||"Error loading script"===a.message||p>=h&&!k?!1:!0;if(!b)return null;p++;d=d||{};var e=c;c=encodeURIComponent;b="/gen_204?atyp=i&ei="+c(google.kEI);google.kEXPI&&(b+="&jexpid="+c(google.kEXPI));b+="&srcpg="+c(google.sn)+"&jsr="+c(r.jsr)+"&bver="+c(r.bv)+("&jsel="+e);e=a.lineNumber;void 0!==e&&(b+="&line="+
# e);var l=a.fileName;l&&(b+="&script="+c(l),e&&l===window.location.href&&(e=document.documentElement.outerHTML.split("\n")[e],b+="&cad="+c(e?e.substring(0,300):"No script found.")));for(var t in d)b+="&",b+=c(t),b+="=",b+=c(d[t]);b=b+"&emsg="+c(a.name+": "+a.message);b=b+"&jsst="+c(a.stack||"N/A");12288<=b.length&&(b=b.substr(0,12288));a=b;k||google.log(0,"",a);return a};window.onerror=function(a,b,d,k,c){q!==a&&(a=c instanceof Error?c:Error(a),void 0===d||"lineNumber"in a||(a.lineNumber=d),void 0===b||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,"SyntaxError"===a.name||"SyntaxError"===a.message.substring(0,11)?2:0));q=null;n&&p>=h&&(window.onerror=null)};})();(function(){
# var c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+Date.now());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);</script><style>body{margin:0 auto;max-width:652px;padding:0 8px;}a{color:#1a0dab;text-decoration:none;tap-highlight-color:rgba(0,0,0,.10)}a:visited{color:#4b11a8}a:hover{text-decoration:underline}img{border:0}html{font-family:arial,sans-serif;font-size:14px;line-height:20px;text-size-adjust:100%;color:#3c4043;word-wrap:break-word;background-color:#fff}.bRsWnc{background-color:#fff;border-top:1px solid #dadce0;height:39px;overflow:hidden}.N6RWV{height:51px;overflow-scrolling:touch;overflow-x:auto;overflow-y:hidden}.Uv67qb{box-pack:justify;font-size:12px;line-height:37px;justify-content:space-between;justify-content:space-between}.Uv67qb a,.Uv67qb span{color:#70757a;display:block;flex:none;padding:0 16px;text-align:center;text-transform:uppercase;}span.OXXup{border-bottom:2px solid #4285f4;color:#4285f4;font-weight:bold}a.eZt8xd:visited{color:#70757a}.FElbsf{border-left:1px solid rgba(0,0,0,.12)}header article{overflow:visible}.Pg70bf{height:39px;display:box;display:flex;display:flex;width:100%}.H0PQec{position:relative;flex:1}.sbc{display:flex;width:100%}.Pg70bf input{margin:2px 4px 2px 8px;}.x{width:26px;color:#70757a;font:27px/38px arial, sans-serif;line-height:40px;}#qdClwb{flex:0 0 auto;width:39px;height:39px;border-bottom:0;padding:0;border-top-right-radius:8px;background-color:#1a73e8;border:1px solid #1558d6;background-image:url(...);}.sc{font-size:16px;position:absolute;top:39px;left:0;right:0;box-shadow:0px 2px 5px rgba(0,0,0,.2);z-index:2;background-color:#fff}.sc>div{padding:10px 10px;padding-left:16px;padding-left:14px;border-top:1px solid #dfe1e5}.scs{background-color:#f8f9fa;}.noHIxc{display:block;font-size:16px;padding:0 0 0 8px;flex:1;height:35px;outline:none;border:none;width:100%;-webkit-tap-highlight-color:rgba(0,0,0,.00);overflow:hidden;}.sbc input[type=text]{background:none}.bz1lBb{background:#fff;border-radius:8px 8px 0 0;box-shadow:0 0 0 1px #dfe1e5;margin-top:24px;}.KP7LCb{border-radius:0 0 8px 8px;box-shadow:0px 1px 0px 1px #dfe1e5;margin-bottom:30px;overflow:hidden}body{margin:0 auto 0 156px;max-width:652px;min-width:652px}.cOl4Id{letter-spacing:-1px;text-align:center;font:22pt Futura, Arial, sans-serif;height:37px;font-smoothing:antialiased;padding:32px 28px 0 24px;position:absolute;left:0;top:0}.cOl4Id span{display:inline-block}.V6gwVd{color:#4285f4}.iWkuvd{color:#ea4335}.cDrQ7{color:#fcc934}.ntlR9{color:#34a853}.tJ3Myc{-webkit-transform:rotate(-20deg);position:relative;left:-1px;display:inline-block}footer{text-align:center;margin-top:18px}footer a,footer a:visited,.smiUbb{color:#70757a}.xeDNfc{margin:0 13px;white-space:nowrap}#EOlPnc{margin-top:36px}#EOlPnc>div{margin:20px}.Srfpq{color:#70757a}</style></head><body jsmodel="hspDDf"><header id="hdr"><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){
# var k=this||self,l=function(a){var b=typeof a;return"object"==b&&null!=a||"function"==b},m=function(a,b){function c(){}c.prototype=b.prototype;a.j=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.l=function(d,e,f){for(var g=Array(arguments.length-2),h=2;h<arguments.length;h++)g[h-2]=arguments[h];return b.prototype[e].apply(d,g)}};var n=Array.prototype.indexOf?function(a,b){return Array.prototype.indexOf.call(a,b,void 0)}:function(a,b){if("string"===typeof a)return"string"!==typeof b||1!=b.length?-1:a.indexOf(b,0);for(var c=0;c<a.length;c++)if(c in a&&a[c]===b)return c;return-1};var p=function(a){return"string"==typeof a.className?a.className:a.getAttribute&&a.getAttribute("class")||""},q=function(a,b){"string"==typeof a.className?a.className=b:a.setAttribute&&a.setAttribute("class",b)},r=function(a,b){a.classList?b=a.classList.contains(b):(a=a.classList?a.classList:p(a).match(/\S+/g)||[],b=0<=n(a,b));return b},v=function(){var a=t,b=u;a.classList?a.classList.remove(b):r(a,b)&&q(a,Array.prototype.filter.call(a.classList?a.classList:p(a).match(/\S+/g)||[],function(c){return c!=
# b}).join(" "))};function w(){var a=k.navigator;return a&&(a=a.userAgent)?a:""};var x=function(a){x[" "](a);return a};x[" "]=function(){};var y=-1!=w().indexOf("Gecko")&&!(-1!=w().toLowerCase().indexOf("webkit")&&-1==w().indexOf("Edge"))&&!(-1!=w().indexOf("Trident")||-1!=w().indexOf("MSIE"))&&-1==w().indexOf("Edge");var z=function(a,b){this.type=a;this.target=b};z.prototype.g=function(){};var A=function(){if(!k.addEventListener||!Object.defineProperty)return!1;var a=!1,b=Object.defineProperty({},"passive",{get:function(){a=!0}});try{k.addEventListener("test",function(){},b),k.removeEventListener("test",function(){},b)}catch(c){}return a}();var C=function(a){z.call(this,a?a.type:"");this.relatedTarget=this.target=null;this.button=this.screenY=this.screenX=this.clientY=this.clientX=0;this.key="";this.keyCode=0;this.metaKey=this.shiftKey=this.altKey=this.ctrlKey=!1;this.state=null;this.pointerId=0;this.pointerType="";this.h=null;if(a){var b=this.type=a.type,c=a.changedTouches&&a.changedTouches.length?a.changedTouches[0]:null;this.target=a.target||a.srcElement;var d=a.relatedTarget;if(d){if(y){a:{try{x(d.nodeName);var e=!0;break a}catch(f){}e=
# !1}e||(d=null)}}else"mouseover"==b?d=a.fromElement:"mouseout"==b&&(d=a.toElement);this.relatedTarget=d;c?(this.clientX=void 0!==c.clientX?c.clientX:c.pageX,this.clientY=void 0!==c.clientY?c.clientY:c.pageY,this.screenX=c.screenX||0,this.screenY=c.screenY||0):(this.clientX=void 0!==a.clientX?a.clientX:a.pageX,this.clientY=void 0!==a.clientY?a.clientY:a.pageY,this.screenX=a.screenX||0,this.screenY=a.screenY||0);this.button=a.button;this.keyCode=a.keyCode||0;this.key=a.key||"";this.ctrlKey=a.ctrlKey;this.altKey=a.altKey;this.shiftKey=a.shiftKey;this.metaKey=a.metaKey;this.pointerId=a.pointerId||0;this.pointerType="string"===typeof a.pointerType?a.pointerType:B[a.pointerType]||"";this.state=a.state;this.h=a;a.defaultPrevented&&C.j.g.call(this)}};m(C,z);var B={2:"touch",3:"pen",4:"mouse"};C.prototype.g=function(){C.j.g.call(this);var a=this.h;a.preventDefault?a.preventDefault():a.returnValue=!1};var D="closure_listenable_"+(1E6*Math.random()|0);var E=0;var F=function(a,b,c,d,e){this.listener=a;this.proxy=null;this.src=b;this.type=c;this.capture=!!d;this.h=e;this.key=++E;this.g=this.i=!1},G=function(a){a.g=!0;a.listener=null;a.proxy=null;a.src=null;a.h=null};var H=function(a){this.src=a;this.g={};this.h=0};H.prototype.add=function(a,b,c,d,e){var f=a.toString();a=this.g[f];a||(a=this.g[f]=[],this.h++);var g;a:{for(g=0;g<a.length;++g){var h=a[g];if(!h.g&&h.listener==b&&h.capture==!!d&&h.h==e)break a}g=-1}-1<g?(b=a[g],c||(b.i=!1)):(b=new F(b,this.src,f,!!d,e),b.i=c,a.push(b));return b};var I="closure_lm_"+(1E6*Math.random()|0),J={},K=0,M=function(a,b,c,d,e){if(d&&d.once)return L(a,b,c,d,e);if(Array.isArray(b)){for(var f=0;f<b.length;f++)M(a,b[f],c,d,e);return null}c=N(c);return a&&a[D]?a.g(b,c,l(d)?!!d.capture:!!d,e):O(a,b,c,!1,d,e)},O=function(a,b,c,d,e,f){if(!b)throw Error("a");var g=l(e)?!!e.capture:!!e,h=P(a);h||(a[I]=h=new H(a));c=h.add(b,c,d,g,f);if(c.proxy)return c;d=Q();c.proxy=d;d.src=a;d.listener=c;if(a.addEventListener)A||(e=g),void 0===e&&(e=!1),a.addEventListener(b.toString(),d,e);else if(a.attachEvent)a.attachEvent(R(b.toString()),d);else if(a.addListener&&a.removeListener)a.addListener(d);else throw Error("b");K++;return c},Q=function(){var a=S,b=function(c){return a.call(b.src,b.listener,c)};return b},L=function(a,b,c,d,e){if(Array.isArray(b)){for(var f=0;f<b.length;f++)L(a,b[f],c,d,e);return null}c=N(c);return a&&a[D]?a.h(b,c,l(d)?!!d.capture:!!d,e):O(a,b,c,!0,d,e)},T=function(a){if("number"!==typeof a&&a&&!a.g){var b=a.src;if(b&&b[D])b.o(a);else{var c=a.type,d=a.proxy;b.removeEventListener?b.removeEventListener(c,d,a.capture):b.detachEvent?b.detachEvent(R(c),d):b.addListener&&b.removeListener&&b.removeListener(d);K--;if(c=P(b)){d=a.type;if(d in c.g){var e=c.g[d],f=n(e,a),g;(g=0<=f)&&Array.prototype.splice.call(e,f,1);g&&(G(a),0==c.g[d].length&&(delete c.g[d],c.h--))}0==c.h&&(c.src=null,b[I]=null)}else G(a)}}},R=function(a){return a in J?J[a]:J[a]="on"+a},S=function(a,b){if(a.g)a=!0;else{b=new C(b,this);var c=a.listener,d=a.h||a.src;a.i&&T(a);a=c.call(d,b)}return a},P=function(a){a=a[I];return a instanceof H?a:null},U="__closure_events_fn_"+(1E9*Math.random()>>>0),N=function(a){if("function"===typeof a)return a;a[U]||(a[U]=function(b){return a.handleEvent(b)});return a[U]};var u,t=document.documentElement,V;function W(){T(V);V=L(t,"mousedown",function(){v();X()},{capture:!0})}function X(){T(V);V=M(t,"keydown",function(a){if(9===a.keyCode){a=t;var b=u;if(a.classList)a.classList.add(b);else if(!r(a,b)){var c=p(a);q(a,c+(0<c.length?" "+b:b))}W()}})};u="zAoYTe";X();}).call(this);</script><div class="cOl4Id"><a href="/?sa=X&amp;ved=0ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQOwgC"><span class="V6gwVd">G</span><span class="iWkuvd">o</span><span class="cDrQ7">o</span><span class="V6gwVd">g</span><span class="ntlR9">l</span><span class="iWkuvd tJ3Myc">e</span></a></div><div class="bz1lBb"><form class="Pg70bf" id="sf"><input name="rlz" type="hidden" value="1C1CHBD_enUS895US895"/><input name="ie" type="hidden" value="ISO-8859-1"/><div clas ...
# var a=document.getElementById("st-toggle"),b=document.getElementById("st-card");a&&b&&a.addEventListener("click",function(c){b.style.display=b.style.display?"":"none";c.preventDefault()},!1);}).call(this);</script></div></div><style>.nGphre{float:right;padding-left:16px}.UykT9d{border-radius:8px;display:block}.nYT7Qb{clear:both}.Gx5Zad{background-color:#fff;margin-bottom:30px;box-shadow:0 0 0 1px #dfe1e5;border-radius:8px}.pkphOe{font-size:14px;line-height:22px;}.EtOod>*:first-child{border-top-left-radius:8px;border-top-right-radius:8px}.EtOod>*:last-child{border-bottom-left-radius:8px;border-bottom-right-radius:8px}.EtOod>.qxDOhb>*:first-child{border-top-left-radius:8px;border-top-right-radius:8px}.EtOod>.qxDOhb>*:last-child{border-bottom-left-radius:8px;border-bottom-right-radius:8px}.n3YsHb .n3YsHb{box-shadow:none;margin-bottom:0px}.kCrYT{padding:12px 16px 12px}.l97dzf{font-weight:400}.zBAuLc{line-height:normal;margin:0;padding:0}.BNeawe{white-space:pre-line;word-wrap:break-word}.deIvCb{font-size:16px;line-height:20px;font-weight:400}.deIvCb.HrGdeb{color:#fff}.deIvCb.AP7Wnd{color:#202124}.tAd8D{font-size:14px;line-height:20px}.tAd8D.HrGdeb{color:rgba(255,255,255,.70)}.tAd8D.AP7Wnd{color:#70757a}.Xdlr0d{overflow-x:auto;-webkit-overflow-scrolling:touch;margin:0 -8px;padding:2px 0 16px 24px;margin-top:-2px;transform:translate3d(0,0,0)}.idg8be{display:table;border-collapse:separate;border-spacing:8px 0;margin:0 -8px;padding-right:16px}.BVG0Nb{display:table-cell;vertical-align:top;background-color:#fff;border-radius:8px;box-shadow:0 0 0 1px #dfe1e5;overflow:hidden}a.fdYsqf{color:#4b11a8}.WddBJd{display:block;margin:0 auto}.RJI4s{vertical-align:middle}.mHhylf{display:table-cell;vertical-align:middle}.WZ5GJf{align-items:center;padding:0 20px;min-width:112px}.qN9Ked,.DXk5Me{margin:0 auto}.DXk5Me{margin-bottom:12px}.Dk7jOe{display:block;margin:0 auto}.Qi9Fd{background:#fff;border:0;border-radius:999px;display:block;height:56px;justify-content:center;width:56px;z-index:0}.Qi9Fd{box-shadow:0 0 0 1px #dfe1e5,inset 0 0 0 0 rgba(0,0,0,0.10),inset 0 0 0 0 rgba(255,255,255,0.50)}.Qi9Fd:focus{outline:none}.Qi9Fd .hWHuJ{display:block;margin:0 auto}.ji5jpf{text-align:center}.xpc .hwc,.xpx .hwx{display:none}.skVgpb{display:table;table-layout:fixed;width:100%}.VGHMXd{display:table-cell;vertical-align:middle;height:52px;text-align:center}.LpaDrb{margin:0 auto 8px;display:block}.vbShOe{padding-top:0}.x54gtf{height:1px;background-color:#dadce0;margin:0 16px}.Q0HXG{height:1px;background-color:#dadce0}.Ap5OSd{padding-bottom:12px}.s3v9rd{font-size:14px;line-height:22px}.s3v9rd.HrGdeb{color:#fff}.s3v9rd.AP7Wnd{color:#202124}.XLloXe{color:#1a0dab;font-size:14px;line-height:20px}a:visited .XLloXe,.XLloXe a:visited{color:#4b11a8}.XLloXe.HrGdeb{color:#fff}a:visited .XLloXe.HrGdeb,.XLloXe.HrGdeb a:visited{color:rgba(255,255,255,.70)}.AVsepf{padding-bottom:8px}.AVsepf.u2x1Od{padding-bottom:0}.Ru8idb{margin-top:-16px}.punez{font-weight:700;letter-spacing:0.75px;text-transform:uppercase}.wyrwXc{font-size:12px;line-height:16px}.wyrwXc.HrGdeb{color:#fff}.wyrwXc.AP7Wnd{color:#202124}.h1hFNe{display:inline-block;position:relative}.Iaa5if{overflow:hidden;position:relative}.l7d08{align-items:center;display:flex;flex-direction:column;justify-content:space-around}hr{border:0;border-bottom:1px solid #dadce0;margin:0}.BUybKe,.HsnFBf{margin-left:16px}.BUybKe,.oM2GA{margin-right:16px}.XO7rhc{margin-right:-16px;margin-left:-16px}.ZM7ZNb{margin-right:-16px}.HbX59e{margin-left:0px}.r2fjmd{margin-bottom:0px;margin-top:0px}.iIWm4b{box-sizing:border-box;min-height:48px}.fLtXsc{padding:14px;position:relative}.Lym8W{width:14px;height:20px;position:relative;margin:0 auto}.xCgLUe{position:absolute;right:16px;margin-top:-10px;top:50%}.Lym8W div{position:absolute;border-left:7px solid transparent;border-right:7px solid transparent;width:0;height:0;left:0}.IyYaEd{top:7px;border-top:7px solid #70757a}.ECUHQe{top:4px;border-top:7px solid #fff}.AeQQub{bottom:7px;border-bottom:7px solid  ...
# 82% · <span class="BNeawe"><a href="/url?q=https://www.rottentomatoes.com/m/avatar&amp;sa=U&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQoiR6BAgMEBI&amp;usg=AOvVaw3-FK5_Db_oHYo7xBcCYr2t"><span class="XLloXe AP7Wnd">Rotten Tomatoes</span></a></span>
# 7.2/10 · <span class="BNeawe"><a href="/url?q=https://www.filmaffinity.com/us/film495280.html&amp;sa=U&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQoiR6BAgMEBQ&amp;usg=AOvVaw2Ao61W21jg3rkfLFLLyGHm"><span class="XLloXe AP7Wnd">FilmAffinity</span></a></span>
# </div></div><div><div class="BNeawe s3v9rd AP7Wnd">On the lush alien world of Pandora live the Na'vi, beings who appear primitive but are highly evolved. Because the planet's environment is poisonous, human/Na'vi hybrids, called Avatars, must link to human minds to allow for free movement on...</div></div></div></div></div><div class="vbShOe kCrYT"><div class="AVsepf"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Release date</span></span>: <span><span class="BNeawe tAd8D AP7Wnd">December 18, 2009 (<span class="BNeawe"><a href="/search?rlz=1C1CHBD_enUS895US895&amp;ie=UTF-8&amp;q=United+States&amp;stick=H4sIAAAAAAAAAOPgE-LUz9U3SCrJMDVRAjMtk83LDbSMspOt9NMyc3LBhFVJRmpiSVFmcmKOQlFqemZ-nkJieWJRKpCTk5pYnKqQkliSuoiVNzQvsyQ1RSG4BMgtBgD3sKM3XAAAAA&amp;sa=X&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQmxN6BAgMEBY"><span class="XLloXe AP7Wnd">USA</span></a></span>)</span></span></div></div><div class="AVsepf"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Director</span></span>: <span><span class="BNeawe tAd8D AP7Wnd"><span class="BNeawe"><a href="/search?rlz=1C1CHBD_enUS895US895&amp;ie=UTF-8&amp;q=James+Cameron&amp;stick=H4sIAAAAAAAAAOPgE-LUz9U3SCrJMDVR4gAxjePTU7TEspOt9NMyc3LBhFVKZlFqckl-0SJWXq_E3NRiBWcgWZSfBwBlCkGLPwAAAA&amp;sa=X&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQmxN6BAgMEBg"><span class="XLloXe AP7Wnd">James Cameron</span></a></span></span></span></div></div><div class="AVsepf"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Starring</span></span>: <span><span class="BNeawe tAd8D AP7Wnd">Sam Worthington; Zoe Saldana; Stephen Lang; Michelle Rodriguez; Sigourney Weaver</span></span></div></div><div class="AVsepf"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Budget</span></span>: <span><span class="BNeawe tAd8D AP7Wnd">237 million USD (2009)</span></span></div></div><div class="AVsepf hwc"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Box office</span></span>: <span><span class="BNeawe tAd8D AP7Wnd">2.847 billion USD</span></span></div></div><div class="AVsepf u2x1Od hwc"><div class="BNeawe s3v9rd AP7Wnd"><span><span class="BNeawe s3v9rd AP7Wnd">Distributed by</span></span>: <span><span class="BNeawe tAd8D AP7Wnd"><span class="BNeawe"><a href="/search?rlz=1C1CHBD_enUS895US895&amp;ie=UTF-8&amp;q=20th+Century+Studios&amp;stick=H4sIAAAAAAAAAOPgE-LUz9U3SCrJMDVRAjMNzUpKjLRkspOt9NMyc3LBhFVKZnFJUWZSaUlqSnxS5SJWESODkgwF59S8ktKiSoXgktKUzPxiAH2OtPxNAAAA&amp;sa=X&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQmxN6BAgMEB0"><span class="XLloXe AP7Wnd">20th Century Studios</span></a></span></span></span></div></div></div><div class="Q0HXG"></div><div><div class="kCrYT"><span class="punez"><div class="BNeawe wyrwXc AP7Wnd">Cast</div></span></div><div><div><div class="Xdlr0d"><div class="idg8be"><a class="BVG0Nb" href="/search?rlz=1C1CHBD_enUS895US895&amp;ie=UTF-8&amp;q=Sam+Worthington&amp;stick=H4sIAAAAAAAAAONgFuLUz9U3SCrJMDVRAjMt0tPyCrSEspOt9NMyc3LBhFVyYnHJIlb-4MRchfD8opKMzLz0kvw8AEuZV8g-AAAA&amp;sa=X&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQ0I4BegQIDBAg"><div><div style="width:112px"><div class="l7d08" style="width:112px;height:112px"><img alt="" class="h1hFNe" data-deferred="1" id="dimg_49" src="..." style="max-width:112px;max-height:112px"/></div><div class="RWuggc kCrYT"><div><div class="BNeawe s3v9rd AP7Wnd">Sam Worthington</div></div><div><div class="BNeawe tAd8D AP7Wnd">Jake Sully, Tommy</div></div></div></div></div></a><a class="BVG0Nb" href="/search?rlz=1C1CHBD_enUS895US895&amp;ie=UTF-8&amp;q=Zoe+Salda%C3%B1a&amp;stick=H4sIAAAAAAAAAONgFuLUz9U3SCrJMDVRAjNNC9PN0rWEspOt9NMyc3LBhFVyYnHJIlaeqPxUheDEnJTEwxsTAb3LRao7AAAA&amp;sa=X&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQ0I4BegQIDBAi"><div><div style="width:112px"><div class="l7d08" style="width:112px;height:112px"><img alt="" class="h1hFNe" data-deferred="1" id="dimg_51" src="..." style="max-width:112px;max-height:112px"/></div><div class="RWuggc kCrYT"><div><di ...
# var h="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},k=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");},l=k(this),m=function(a,b){if(b)a:{var c=l;a=a.split(".");for(var e=0;e<a.length-1;e++){var d=a[e];if(!(d in
# c))break a;c=c[d]}a=a[a.length-1];e=c[a];b=b(e);b!=e&&null!=b&&h(c,a,{configurable:!0,writable:!0,value:b})}};m("Object.is",function(a){return a?a:function(b,c){return b===c?0!==b||1/b===1/c:b!==b&&c!==c}});m("Array.prototype.includes",function(a){return a?a:function(b,c){var e=this;e instanceof String&&(e=String(e));var d=e.length;c=c||0;for(0>c&&(c=Math.max(c+d,0));c<d;c++){var g=e[c];if(g===b||Object.is(g,b))return!0}return!1}});m("String.prototype.includes",function(a){return a?a:function(b,c){if(null==this)throw new TypeError("The 'this' value for String.prototype.includes must not be null or undefined");if(b instanceof RegExp)throw new TypeError("First argument to String.prototype.includes must not be a regular expression");return-1!==(this+"").indexOf(b,c||0)}});var n=this||self;var p=function(a){var b=a.url;a=a.l;this.i=b;this.o=a;a=/[?&]dsh=1(&|$)/.test(b);this.h=!a&&/[?&]ae=1(&|$)/.test(b);this.s=!a&&/[?&]ae=2(&|$)/.test(b);if((this.g=/[?&]adurl=([^&]*)/.exec(b))&&this.g[1]){try{var c=decodeURIComponent(this.g[1])}catch(e){c=null}this.j=c}},r=function(a,b){return a.h&&a.j||a.s?1==b?a.h?a.j:q(a,"&dct=1"):2==b?q(a,"&ri=2"):q(a,"&ri=16"):a.i},q=function(a,b){return a.g?a.i.slice(0,a.g.index)+b+a.i.slice(a.g.index):a.i+b},t=function(a){a=a.o;var b=encodeURIComponent,c="";a.platform&&(c+="&uap="+b(a.platform));a.platformVersion&&(c+="&uapv="+b(a.platformVersion));a.uaFullVersion&&(c+="&uafv="+b(a.uaFullVersion));a.architecture&&(c+="&uaa="+b(a.architecture));a.model&&(c+="&uam="+b(a.model));a.bitness&&(c+="&uab="+b(a.bitness));a.fullVersionList&&(c+="&uafvl="+b(a.fullVersionList.map(function(e){return b(e.brand)+";"+b(e.version)}).join("|")));"undefined"!==typeof a.wow64&&(c+="&uaw="+Number(a.wow64));return c};var v=function(a,b){this.g=b===u?a:""};v.prototype.toString=function(){return this.g+""};v.prototype.i=!0;v.prototype.h=function(){return this.g.toString()};var w=function(a){return a instanceof v&&a.constructor===v?a.g:"type_error:TrustedResourceUrl"},u={};var y=function(a,b){this.g=b===x?a:""};y.prototype.toString=function(){return this.g.toString()};y.prototype.i=!0;y.prototype.h=function(){return this.g.toString()};var z=function(a){return a instanceof y&&a.constructor===y?a.g:"type_error:SafeUrl"},A=/^(?:(?:https?|mailto|ftp):|[^:/?#]*(?:[/?#]|$))/i,B=function(a){if(a instanceof y)return a;a="object"==typeof a&&a.i?a.h():String(a);A.test(a)||(a="about:invalid#zClosurez");return new y(a,x)},x={},C=new y("about:invalid#zClosurez",x);var D=/^((market|itms|intent|itms-appss):\/\/)/i;
# var E=function(a){this.A=a};function F(a){return new E(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})}var G=[F("data"),F("http"),F("https"),F("mailto"),F("ftp"),new E(function(a){return/^[^:]*([/?#]|$)/.test(a)})];var H=function(a,b){b=b instanceof y?b:B(b);a.href=z(b)},I=/^[\w+/_-]+[=]{0,2}$/;function J(a,b){var c=/[?&]adurl=/.exec(b);return c?""+b.slice(0,c.index+1)+a+"&"+b.slice(c.index+1):""+b+(-1===b.indexOf("?")?"?":"&")+a}function K(a,b){a=a.href;var c=/[?&]nis=([^&]*)/.exec(a);return c&&c[1]===b?a:c?a.replace(/([?&])nis=([^&]*)/,function(e,d){return d+"nis="+b}):J("nis="+b,a)}function L(){var a;return!(null==(a=document.featurePolicy)||!a.allowedFeatures().includes("attribution-reporting"))};var M=new function(){var a={v:google.eufsv},b=this;a=(void 0===a?{}:a).v;this.g=null;a&&navigator.userAgentData&&navigator.userAgentData.getHighEntropyValues&&(a=navigator.userAgentData.getHighEntropyValues("platform platformVersion uaFullVersion architecture model bitness fullVersionList wow64".split(" ")))&&a.then(function(c){b.g=c})};function N(a,b,c){if(a=a.dataset[b])for(a=a.split(","),b=0;b<a.length;b++){var e=document.createElement("link"),d=a[b],g=c;e.rel=g;if(-1!=g.toLowerCase().indexOf("stylesheet")){e.href=w(d).toString();a:{d=(e.ownerDocument&&e.ownerDocument.defaultView||n).document;if(d.querySelector&&(d=d.querySelector('style[nonce],link[rel="stylesheet"][nonce]'))&&(d=d.nonce||d.getAttribute("nonce"))&&I.test(d))break a;d=""}d&&e.setAttribute("nonce",d)}else e.href=d instanceof v?w(d).toString():d instanceof y?z(d):z(B(d));document.head.appendChild(e)}}
# function O(a,b){if(b){N(b,"pcu","preconnect");N(b,"pfu","prefetch");if(b.hasAttribute("data-impdclcc"))try{var c=b.hasAttribute("attributionsourceid")&&b.hasAttribute("attributeon")&&b.hasAttribute("attributiondestination")?"2":b.hasAttribute("attributionsrc")?L()?"6":"5":L()?"7":"8";var e=K(b,c);var d=void 0===d?G:d;a:{c=d;c=void 0===c?G:c;for(d=0;d<c.length;++d){var g=c[d];if(g instanceof E&&g.A(e)){var f=new y(e,x);break a}}f=void 0}b.href=z(f||C)}catch(Q){}b.hasAttribute("data-ae")&&(b.hasAttribute("data-ohref")?e=b.getAttribute("data-ohref"):(e=b.href,b.setAttribute("data-ohref",e)),g=e,f={l:M.g},f=new p({url:g,l:(void 0===f?{}:f).l}),f.h&&f.j||f.s?navigator.sendBeacon?(g=navigator,c=g.sendBeacon,d="&act=1&ri=1",f.h&&f.o&&(d+=t(f)),f=c.call(g,q(f,d),"")?r(f,1):r(f,2)):f=r(f,0):f=g,f=f instanceof y||!D.test(f)?f:new y(f,x),e!=f&&H(b,f));b.hasAttribute("data-ems")&&a.stopPropagation()}}
# function P(a){if(a.dataset){var b=a.dataset.rw;if(b){var c;a:{if(a&&(c=a.dataset.ved)){c="&ved="+c;break a}c=""}H(a,b+c)}}}window.IMVCy=function(a){O(a,a.currentTarget)};window.YvikHb=O;window.TPUtub=P;window.J4LCUe=P;}).call(this);</script><div class="uEierd"><div><div class="Gx5Zad fP1Qef EtOod pkphOe"><div class="v5yQqb jqWpsc"><a class="cz3goc BmP5tf" data-al="1" href="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABAAGgJ5bQ&amp;sig=AOD64_1miI8_Egw_IIidc3egg1MaDmmUDA&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQ0Qx6BAgOEAE&amp;adurl=" role="presentation"><div aria-level="3" class="CCgQ5 MUxGbd v0nnCb aLF0Z OSrXXb" role="heading"><span>Full Avatar Movie Free - Watch Full Movies Online Free</span></div><div aria-label="www.chilimovie.com/free/movie" class="d8lRkd OSrXXb MUxGbd lyLwlc aLF0Z" role="link"><span class="CnP9N U3A9Ac qV8iec">Ad</span><span aria-hidden="true" class="qzEoUe" data-dtld="chilimovie.com" role="text">www.chilimovie.com/free/movie</span></div></a><span></span></div><w-ad-creative-spacer><div class="oru2pc" style="height:12px"></div></w-ad-creative-spacer><div class="w1C3Le"><div class="MUxGbd yDYNvb lyLwlc"><div>Infinite Free Full Movies Online Full Avatar Movie. No Signup.No Download. High-Quality Movies &amp; Start Watching Now! HD Streaming. High-Quality Movies. 68,000+ Movies.</div></div></div><w-ad-creative-spacer><div class="oru2pc" style="height:12px"></div></w-ad-creative-spacer><div class="bOeY0b BmP5tf"><div class="XUpIGb MUxGbd lyLwlc aLF0Z OSrXXb"><a data-agdh="fvd3vc" data-al="1" data-rw="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABACGgJ5bQ&amp;sig=AOD64_3FXvJwUa7deF8f6Fi_T9UtMTvkpA&amp;adurl" data-ved="2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQpigoAHoECA4QAw" href="#">Free Movies</a> · <a data-agdh="fvd3vc" data-al="1" data-rw="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABAFGgJ5bQ&amp;sig=AOD64_0GvTrdbZ__PscHjbtaTcMuKha40w&amp;adurl" data-ved="2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQpigoAXoECA4QBA" href="#">Contact Us</a></div></div></div></div></div><div class="uEierd"><div><div class="Gx5Zad fP1Qef EtOod pkphOe"><div class="v5yQqb jqWpsc"><a class="cz3goc BmP5tf" data-al="1" href="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABABGgJ5bQ&amp;sig=AOD64_0h-Il0FAm7J7fAVX3r7H2d5LKwqQ&amp;ved=2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQ0Qx6BAgNEAE&amp;adurl=" role="presentation"><div aria-level="3" class="CCgQ5 MUxGbd v0nnCb aLF0Z OSrXXb" role="heading"><span>HD 1080p High Quality - Avatar 2009 full movie</span></div><div aria-label="us.tomatomovies.com/movies/free" class="d8lRkd OSrXXb MUxGbd lyLwlc aLF0Z" role="link"><span class="CnP9N U3A9Ac qV8iec">Ad</span><span aria-hidden="true" class="qzEoUe" data-dtld="tomatomovies.com" role="text">us.tomatomovies.com/movies/free</span></div></a><span></span></div><w-ad-creative-spacer><div class="oru2pc" style="height:12px"></div></w-ad-creative-spacer><div class="w1C3Le"><div class="MUxGbd yDYNvb lyLwlc"><div>Find Where to Watch Free Movies and TV Shows with Our Free Streaming Guide. We Make Finding and Watching Your Favorite Movies and Shows Fast, Easy, and Free.</div></div></div><w-ad-creative-spacer><div class="oru2pc" style="height:12px"></div></w-ad-creative-spacer><div class="bOeY0b BmP5tf"><div class="XUpIGb MUxGbd lyLwlc aLF0Z OSrXXb"><a data-agdh="fvd3vc" data-al="1" data-rw="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABADGgJ5bQ&amp;sig=AOD64_2mMUhYJbLElYkOSK2RA8WIb-hW7Q&amp;adurl" data-ved="2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQpigoAHoECA0QAw" href="#">Sonic the Hedgehog 2</a> · <a data-agdh="fvd3vc" data-al="1" data-rw="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4AhUayJQJHTuXCjgYABAEGgJ5bQ&amp;sig=AOD64_0HPnZFxzeg0G0WTwTe-gVFUo-xBA&amp;adurl" data-ved="2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQpigoAXoECA0QBA" href="#">Scream 2022</a> · <a data-agdh="fvd3vc" data-al="1" data-rw="http://www.google.com/aclk?sa=l&amp;ai=DChcSEwjduP69wun4A ...
# var f=this||self,g=function(a){return a};var h,k=function(){if(void 0===h){var a=null,b=f.trustedTypes;if(b&&b.createPolicy){try{a=b.createPolicy("goog#html",{createHTML:g,createScript:g,createScriptURL:g})}catch(c){f.console&&f.console.error(c.message)}h=a}else h=a}return h};var p=function(a,b){this.h=a===l&&b||"";this.g=m},q=function(a){return a instanceof p&&a.constructor===p&&a.g===m?a.h:"type_error:Const"},m={},l={};var t=function(a,b){this.g=b===r?a:""};t.prototype.toString=function(){return this.g+""};var u=function(a){return a instanceof t&&a.constructor===t?a.g:"type_error:TrustedResourceUrl"},y=function(){var a={},b=q(new p(l,"/complete/search"));if(!v.test(b))throw Error("a`"+b);var c=b.replace(w,function(e,d){if(!Object.prototype.hasOwnProperty.call(a,d))throw Error("b`"+d+"`"+b+"`"+JSON.stringify(a));e=a[d];return e instanceof p?q(e):encodeURIComponent(String(e))});return x(c)},w=/%{(\w+)}/g,v=RegExp("^((https:)?//[0-9a-z.:[\\]-]+/|/[^/\\\\]|[^:/\\\\%]+/|[^:/\\\\%]*[?#]|about:blank#)","i"),z=/^([^?#]*)(\?[^#]*)?(#[\s\S]*)?/,r={},x=function(a){var b=k();a=b?b.createScriptURL(a):a;return new t(a,r)},A=function(a,b,c){if(null==c)return b;if("string"===typeof c)return c?a+encodeURIComponent(c):"";for(var e in c)if(Object.prototype.hasOwnProperty.call(c,e)){var d=c[e];d=Array.isArray(d)?d:[d];for(var n=0;n<d.length;n++){var P=d[n];null!=P&&(b||(b=a),b+=(b.length>a.length?"&":"")+encodeURIComponent(e)+"="+encodeURIComponent(String(P)))}}return b};var B={},C=function(a,b){this.g=b===B?a:""};C.prototype.toString=function(){return this.g.toString()};var D=function(a){var b=k();a=b?b.createHTML(a):a;return new C(a,B)};
# function E(a,b){if(void 0!==a.tagName){if("script"===a.tagName.toLowerCase())throw Error("c");if("style"===a.tagName.toLowerCase())throw Error("d");}a.innerHTML=b instanceof C&&b.constructor===C?b.g:"type_error:SafeHtml"};var F=document.querySelector(".l"),G=document.querySelector("#sf"),H=G.querySelector(".sbc"),I=G.querySelector("[type=text]"),J=G.querySelector("[type=submit]"),K=G.querySelector(".sc"),L=G.querySelector(".x"),M=I.value,N=[],O=-1,Q=M,R,S,T;M||(L&&(L.style.display="none"),U(!1));function U(a){if(H.classList.contains("esbc")){var b=H.classList.contains("chsbc"),c=H.classList.contains("rtlsbc");a&&(K.style.display="block",b?(G.style.borderRadius="20px 20px 0 0",K.style.borderBottom="1px solid #DFE1E5",J.style.borderRadius=c?"20px 0 0 0":"0 20px 0 0"):H.style.borderRadius=c?"0 8px 0 0":"8px 0 0 0");a||(K.style.display="none",b?(G.style.borderRadius="20px",K.style.borderBottom="none",J.style.borderRadius=c?"20px 0 0 20px":"0 20px 20px 0"):H.style.borderRadius=c?"0 8px 8px 0":"8px 0 0 8px")}}function V(){G.querySelector("[name=oq]").value=Q;G.querySelector("[name=aqs]").value="heirloom-srp."+(0<=O?O:"")+"."+(0<N.length?"0l"+N.length:"")}
# function W(){R=null;if(S){var a={client:"heirloom-srp",hl:hl,json:"t",callback:"hS",q:S};"undefined"!==typeof ds&&ds&&(a.ds=ds);var b=document;var c="SCRIPT";"application/xhtml+xml"===b.contentType&&(c=c.toLowerCase());c=b.createElement(c);b=y();b=z.exec(u(b).toString());var e=b[3]||"";a=x(b[1]+A("?",b[2]||"",a)+A("#",e));c.src=u(a);var d,n;(d=(a=null==(n=(d=(c.ownerDocument&&c.ownerDocument.defaultView||window).document).querySelector)?void 0:n.call(d,"script[nonce]"))?a.nonce||a.getAttribute("nonce")||
# "":"")&&c.setAttribute("nonce",d);document.body.appendChild(c);S=null;R=setTimeout(W,500)}}function X(){for(;K.firstChild;)K.removeChild(K.firstChild);N=[];O=-1;U(!1)}function Y(){var a=K.querySelector(".scs");a&&(a.className="");0<=O?(a=K.childNodes[O],a.className="scs",M=a.textContent):M=Q;I.value=M}I.addEventListener("focus",function(){F&&(F.style.display="none")},!1);I.addEventListener("blur",function(){X();F&&(F.style.display="")},!1);I.addEventListener("keyup",function(a){M=I.value;T=!1;13===a.which?V():27===a.which?(X(),F&&(F.style.display=""),M=Q,I.value=M):40===a.which?(O++,O>=N.length&&(O=-1),Y()):38===a.which?(O--,-1>O&&(O=N.length-1),Y()):(a=M)?(L&&(L.style.display=""),S=a,R||W(),Q=a):(L&&(L.style.display="none"),U(!1),X(),Q="",T=!0)},!1);J.addEventListener("click",V,!1);L.addEventListener("click",function(){I.value="";L.style.display="none";U(!1)},!1);H.addEventListener("click",function(){I.focus()},!1);window.hS=function(a){if(!T){X();0===a[1].length&&U(!1);for(var b=0;b<a[1].length;b++){var c=a[1][b][0],e=document.createElement("div");E(e,D(c));e.addEventListener("mousedown",function(d){d.preventDefault();return!1},!1);c=c.replace(/<\/?b>/g,"");e.addEventListener("click",function(d){return function(){O=d;V();Y();X();G.submit()}}(b),!1);e.addEventListener("mouseover",function(d){return function(){O!==d&&(O=d,Y())}}(b),!1);K.appendChild(e);U(!0);N.push(c)}}};}).call(this);})();(function(){
# window.prh=function(d,a){a=a.split(",");for(var b=0;b<a.length;b++){var c=document.createElement("link");c.rel=d;c.href=a[b];(document.head||document.querySelector("head")).appendChild(c)}};}).call(this);(function(){
# function b(a){for(a=a.target||a.srcElement;a&&"A"!==a.nodeName;)a=a.parentElement;a&&(a.href||"").match(/\/search.*[?&]tbm=isch/)&&(a.href+="&biw="+document.documentElement.clientWidth,a.href+="&bih="+document.documentElement.clientHeight)}document.addEventListener("click",b,!1);document.addEventListener("touchStart",b,!1);}).call(this);</script></div><!-- cctlcm 0 cctlcm --><textarea class="csi" name="csi" style="display:none"></textarea><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var e='Y0HIYtbfEqTKwbkPn8i5kA8';var sn='web';var timl=false;(function(){
# function y(a){if(!a||z(a))return 0;if(!a.getBoundingClientRect)return 1;var c=function(b){return b.getBoundingClientRect()};return A(a,c)?0:K(a,c)}function A(a,c){var b;a:{for(b=a;b&&null!==b;b=b.parentElement)if("hidden"===b.style.overflow)break a;b=null}if(!b)return!1;a=c(a);c=c(b);return a.bottom<c.top||a.top>=c.bottom||a.right<c.left||a.left>=c.right}
# function z(a){return"none"===a.style.display?!0:document.defaultView&&document.defaultView.getComputedStyle?(a=document.defaultView.getComputedStyle(a),!!a&&("hidden"===a.visibility||"0px"===a.height&&"0px"===a.width)):!1}
# function K(a,c){var b=c(a);a=b.left+window.pageXOffset;c=b.top+window.pageYOffset;var f=b.width;b=b.height;var g=0;if(0>=b&&0>=f)return g;var p=window.innerHeight||document.documentElement.clientHeight;0>c+b?g=2:c>=p&&(g=4);if(0>a+f||a>=(window.innerWidth||document.documentElement.clientWidth))g|=8;g||(g=1,c+b>p&&(g|=4));return g};var L=e,M=sn,N="undefined"===typeof de?!0:!1!==de,O=[];function P(a,c,b){a="/gen_204?atyp=csi&s="+(M||"web")+"&t="+a+("&lite=1&ei="+L+"&conn="+(window.navigator&&window.navigator.connection?window.navigator.connection.type:-1)+c);c="&rt=";for(var f in b)a+=""+c+f+"."+b[f],c=",";return a}function Q(a){a={prt:a};window.wsrt&&(a.wsrt=window.wsrt);return a}function R(a){window.ping?window.ping(a):(new Image).src=a}
# (function(){for(var a=(new Date).getTime()-window.start,c=Q(a),b=0,f=0,g=0,p=document.getElementsByTagName("img"),q=N?"&biw="+window.innerWidth+"&bih="+window.innerHeight:"",S=function(h,r){h.onload=function(){f=(new Date).getTime()-window.start;r&&++u==g&&(b=f,B());h.onload=null}},B=function(){q+="&ima="+g;c.aft=b;R(P("aft",q,c))},u=0,T=0,d=void 0;d=p[T++];){var t=y(d),n=!!(t&1);n&&++g;var l=d.hasAttribute("data-ilite"),v=d.hasAttribute("data-deferred")||l,C=d.getAttribute("data-src")||d.getAttribute("data-lzysrc"),D=!v&&C;O.push([t,v,D,google.ldi&&d.id&&google.ldi[d.id]||l&&C]);l=(t=d.complete&&(l||!v&&!(n&&D)))&&Number(d.getAttribute("data-iml"))||0;t&&l?(n&&++u,l&&(d=l-window.start,n&&(b=Math.max(b,d)),f=Math.max(f,d))):S(d,n)}b||(b=a);f||(f=b);u==g&&B();google.rglh&&google.rglh();window.addEventListener("load",function(){window.setTimeout(function(){c.ol=(new Date).getTime()-window.start;timl&&(c.iml=f);var h=window.performance&&window.performance.timing;h&&(c.rqst=h.responseEnd-h.requestStart,c.rspt=h.responseEnd-
# h.responseStart);for(var r=h=0,E=0,F=0,G=0,H=0,U=0,k;k=O[U++];){var m=k[0],w=k[1],I=k[2];k=k[3];var V=0==m,x=m&8,J=m&4;(m=1==m||2==m||x&&!J)&&!x&&(w&&!k||++E,I&&++H);w&&(m&&k&&++h,J&&!k&&++r);V||x?I||++G:w||++F}q+="&ime="+E+"&imel="+H+("&imex="+F+"&imeh="+G)+("&imea="+h+"&imeb="+r);R(P("all",q,c))},0)},!1)})();}).call(this);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){prh('preconnect', 'http://www.googleadservices.com/')})();
# function _setImagesSrc(e,d){function f(b){b.onerror=function(){b.style.display="none"};b.src=d}for(var g=0,a=void 0;a=e[g++];){var c=document.getElementById(a)||document.querySelector('img[data-iid="'+a+'"]');c?(a=void 0,(null==(a=google.c)?0:a.setup)&&google.c.setup(c),f(c)):(google.iir=google.iir||{},google.iir[a]=d)}}"undefined"==typeof window.google&&(window.google={});</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_39'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_41'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_43'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_45'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='...\x3d';var i=['dimg_47','dimg_13'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_49'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_51'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_53'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_55'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_57'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_59'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_3'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_1'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_5'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d';var i=['dimg_7'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_9'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_11'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...';var i=['dimg_15'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/jpeg;base64,...\x3d\x3d';var i=['dimg_19'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var s='data:image/png;base64,...\x3d';var i=['dimg_23','dimg_25','dimg_27','dimg_29','dimg_31','dimg_33','dimg_35','dimg_37'];_setImagesSrc(i,s);})();</script><script nonce="xsAPIbUWOuBLrHu6ZQQdxQ">(function(){var e='Y0HIYtbfEqTKwbkPn8i5kA8';(function(){
# var a=e;2===(window.performance&&window.performance.navigation&&window.performance.navigation.type)&&window.ping("/gen_204?ct=backbutton&ei="+a);}).call(this);})();(function(){
# var b=[function(){google.tick&&google.tick("load","dcl")}];google.dclc=function(a){b.length?b.push(a):a()};function c(){for(var a=b.shift();a;)a(),a=b.shift()}window.addEventListener?(document.addEventListener("DOMContentLoaded",c,!1),window.addEventListener("load",c,!1)):window.attachEvent&&window.attachEvent("onload",c);}).call(this);
# window.jsl=window.jsl||{};window.jsl.dh=function(a,b,f){try{var g=document.getElementById(a);if(g)g.innerHTML=b,f&&f();else{var c={id:a,script:String(!!f),milestone:String(google.jslm||0)};google.jsla&&(c.async=google.jsla);var h=a.indexOf("_"),d=0<h?a.substring(0,h):"",k=document.createElement("div");k.innerHTML=b;var e=k.children[0];if(e&&(c.tag=e.tagName,c["class"]=String(e.className||null),c.name=String(e.getAttribute("jsname")),d)){a=[];var l=document.querySelectorAll('[id^="'+d+'_"]');for(b=0;b<l.length;++b)a.push(l[b].id);c.ids=a.join(",")}google.ml(Error(d?"Missing ID with prefix "+d:"Missing ID"),!1,c)}}catch(m){google.ml(m,!0,{"jsl.dh":!0})}};(function(){var x=false;
# google.jslm=x?2:1;})();(function(){(function(){google.csct={};google.csct.ps='AOvVaw3STXXAqErlhrhhYgme4am2\x26ust\x3d1657377507346457';})();})();(function(){(function(){google.csct.rd=true;})();})();(function(){(function(){google.csct.rl=true;})();})();(function(){
# window.xp=function(b){function f(k,g,h){return"xp"+("x"==g?"c":"x")+h}for(var c=/\bxp(x|c)(\d?)\b/,a=b;a;){var e=a.className,d=e.match(c);if(d){d="c"==d[1];a.className=e.replace(c,f);b&&b.setAttribute("aria-expanded",d);if(d)for(b=a.getElementsByTagName("img"),c=0;c<b.length;++c)if(a=b[c],e=a.getAttribute("data-ll"))a.src=e,a.removeAttribute("data-ll");break}a=a.parentElement}};})();(function(){(function(){var id='tsuid8';var lve=false;(function(){
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# a.tagName).toUpperCase()in k&&32==c)||((b=a.tagName in f)||(b=a.getAttributeNode("tabindex"),b=null!=b&&b.specified),b=!(b&&!a.disabled));if(b)c=!1;else{b=(a.getAttribute("role")||a.type||a.tagName).toUpperCase();var m=!(b in h)&&13==c;a="INPUT"!=a.tagName.toUpperCase()||!!a.type;c=(0==h[b]%c||m)&&a}}c&&(d.preventDefault(),window.xp(this),lve&&window.logVe(this))};}).call(this);})();})();(function(){(function(){
# window.logVe=function(a){a&&a.attributes["data-ved"]&&window.ping("/gen_204?ved="+a.attributes["data-ved"].value)};}).call(this);})();(function(){(function(){var id='tsuid2';var lve=true;(function(){
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# ...
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# a.tagName).toUpperCase()in k&&32==c)||((b=a.tagName in f)||(b=a.getAttributeNode("tabindex"),b=null!=b&&b.specified),b=!(b&&!a.disabled));if(b)c=!1;else{b=(a.getAttribute("role")||a.type||a.tagName).toUpperCase();var m=!(b in h)&&13==c;a="INPUT"!=a.tagName.toUpperCase()||!!a.type;c=(0==h[b]%c||m)&&a}}c&&(d.preventDefault(),window.xp(this),lve&&window.logVe(this))};}).call(this);})();})();(function(){window.jsl.dh('accdef_11','\x3cdiv\x3e\x3cdiv style\x3d\x22padding-bottom:12px;padding-top:0px\x22 class\x3d\x22hwc kCrYT\x22\x3e\x3cdiv class\x3d\x22yStFkb\x22\x3e\x3cdiv class\x3d\x22Gx5Zad xpd EtOod pkphOe\x22\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3e2009\x27s Avatar took \x3cspan class\x3d\x22FCUp0c rQMQod\x22\x3eten years\x3c/span\x3e to make\u2014Cameron and his team had to essentially invent new moviemaking technology on the spot, which they used to make one of the most visually mind-blowing fantasy films ever made.\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv class\x3d\x22x54gtf\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22kCrYT\x22\x3e\x3ca href\x3d\x22/url?q\x3dhttps://www.vanityfair.com/hollywood/2017/04/avatar-sequels-james-cameron-release-dates\x26amp;sa\x3dU\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQFXoECAsQGw\x26amp;usg\x3dAOvVaw0pVkadjoHxsRzYEgnTkx7t\x22\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe vvjwJb AP7Wnd\x22\x3e\x3cspan class\x3d\x22rQMQod Xb5VRe\x22\x3eAt Long Last, Those Four Avatar Sequels Have Release Dates\x3c/span\x3e\x3c/div\x3e\x3c/span\x3e\x3cspan\x3e\x3cdiv class\x3d\x22BNeawe UPmit AP7Wnd\x22\x3ewww.vanityfair.com \u203a hollywood \u203a 2017/04 \u203a avatar-sequels-james-camer...\x3c/div\x3e\x3c/span\x3e\x3c/a\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22P1NWSe\x22\x3e\x3cdiv class\x3d\x22wOMIed nkPlDb\x22\x3e\x3cspan class\x3d\x22JhFlyf VQFmSd\x22\x3e\x3ca class\x3d\x22f4J0H\x22 href\x3d\x22https://www.google.com/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;ei\x3dY0HIYtbfEqTKwbkPn8i5kA8\x26amp;q\x3dHow+long+did+it+take+to+film+Avatar+2009?\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQzmd6BAgLEB0\x22\x3eMore results\x3c/a\x3e\x3c/span\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e');})();(function(){(function(){var id='tsuid1';var lve=true;(function(){
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# a.tagName).toUpperCase()in k&&32==c)||((b=a.tagName in f)||(b=a.getAttributeNode("tabindex"),b=null!=b&&b.specified),b=!(b&&!a.disabled));if(b)c=!1;else{b=(a.getAttribute("role")||a.type||a.tagName).toUpperCase();var m=!(b in h)&&13==c;a="INPUT"!=a.tagName.toUpperCase()||!!a.type;c=(0==h[b]%c||m)&&a}}c&&(d.preventDefault(),window.xp(this),lve&&window.logVe(this))};}).call(this);})();})();(function(){(function(){var id='tsuid4';var lve=true;(function(){
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# a.tagName).toUpperCase()in k&&32==c)||((b=a.tagName in f)||(b=a.getAttributeNode("tabindex"),b=null!=b&&b.specified),b=!(b&&!a.disabled));if(b)c=!1;else{b=(a.getAttribute("role")||a.type||a.tagName).toUpperCase();var m=!(b in h)&&13==c;a="INPUT"!=a.tagName.toUpperCase()||!!a.type;c=(0==h[b]%c||m)&&a}}c&&(d.preventDefault(),window.xp(this),lve&&window.logVe(this))};}).call(this);})();})();(function(){window.jsl.dh('accdef_5','\x3cdiv\x3e\x3cdiv style\x3d\x22padding-bottom:12px\x22 class\x3d\x22hwc\x22\x3e\x3cdiv class\x3d\x22AzWLW\x22\x3e\x3cdiv class\x3d\x22Gx5Zad xpd EtOod pkphOe\x22\x3e\x3cdiv class\x3d\x22FybcKc\x22\x3e\x3cdiv\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22Xdlr0d\x22\x3e\x3cdiv class\x3d\x22idg8be\x22\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dAvengers\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLSz9U3MDOqyjXNMBLNzS_JzM9TSE4sKCktSlXIzS_LTC2OEkgsSyxJLFIwMjCwVEjLzMk9xQjWlZ6blG2YfoqRA8RJKYo3OcXIq5-ub2iYVmWWYlmRmwxVBzH9FCM3iGNoZJZkkV12ipETxDPPq8grhyozNcpLiS-DcpJKKtNMq6CcvJTyEiOYspystDTj5F-Mor7YHLuIlcOxLDUvPbWo-BabJIPpx1am-qrDG3fI1XbeedCq1OLyh509xqMYAMOsePr5AAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAP\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcRPtx0YI9gQbBUO8iBRBX02kSxgeiuBXMnSVHZfog\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eThe Avengers\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/a\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dAvengers:+Endgame\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLWz9U3MDQyS7LILjMSzc0vyczPU0hOLCgpLUpVyM0vy0wtjhJILEssSSxSMDIwsFRIy8zJPcXIBdKWnpuUbZh-ipEDxEkpijc5xcirn65vaJhWZZZiWZGbDFVnZlSVa5pxihHZrlOMnCCeeV5FXjlUmalRXkp8GZSTVFKZZloF5eSllJcYwZTlZKWlGSf_YhT1xebYRayCjmWpeempRcVWCq55KemJuam32CQZTD-2MtVXHd64Q662886DVqUWlz_s7DEexQB3OaJIAwEAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAQ\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcT-7gN2fnKEziM_wa7aCOWRzYRVr9b4FSxoE4_ePA\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eAvengers: Endgame\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/a\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dBeowulf+2007\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLUz9U3MM-ryCs3Es3NL8nMz1NITiwoKS1KVcjNL8tMLY4SSCxLLEksUjAyMLBUSMvMyT3FyAXSlJ6blG2YfoqRA8RJKYo3OcXIq5-ub2iYVmWWYlmRmwxVZ2ZUlWuacYqRG8QxNDJLssguO8WIsBeqzNQoLyW-DMpJKqlMM62CcvJSykuMYMpystLSjJN_MYr6YnPsIlYep9T88tKcNJBzzW-xSTKYfmxlqq86vHGHXG3nnQetSi0uf9jZYzyKAbHiGs38AAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAR\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcQ32zf0tv9uGqhXm9fB2G-ASPk_bU4Yx2BaRJDmnw\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eBeowulf\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/a\x3e\x3ca class\x3d\x22BVG0Nb\x ...
#
#
# var e="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),f={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1},g={Enter:13," ":32},h={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},k={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},l={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0};document.getElementById(id).onclick=function(){window.xp(this);lve&&window.logVe(this)};document.getElementById(id).onkeydown=function(d){var c=d.which||d.keyCode;!c&&d.key&&(c=g[d.key]);e&&3==c&&(c=13);if(13!=c&&32!=c)c=!1;else{var a=d.target||d.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);var b;if(!(b="keydown"!=d.type)){if(b="getAttribute"in a)b=!((a.getAttribute("type")||a.tagName).toUpperCase()in l);b=!(b&&!("BUTTON"==a.tagName.toUpperCase()||a.type&&"FILE"==a.type.toUpperCase())&&!a.isContentEditable)}(b=b||d.ctrlKey||d.shiftKey||d.altKey||d.metaKey||(a.getAttribute("type")||
# a.tagName).toUpperCase()in k&&32==c)||((b=a.tagName in f)||(b=a.getAttributeNode("tabindex"),b=null!=b&&b.specified),b=!(b&&!a.disabled));if(b)c=!1;else{b=(a.getAttribute("role")||a.type||a.tagName).toUpperCase();var m=!(b in h)&&13==c;a="INPUT"!=a.tagName.toUpperCase()||!!a.type;c=(0==h[b]%c||m)&&a}}c&&(d.preventDefault(),window.xp(this),lve&&window.logVe(this))};}).call(this);})();})();(function(){window.jsl.dh('accdef_9','\x3cdiv\x3e\x3cdiv style\x3d\x22padding-bottom:12px\x22 class\x3d\x22hwc\x22\x3e\x3cdiv class\x3d\x22AzWLW\x22\x3e\x3cdiv class\x3d\x22Gx5Zad xpd EtOod pkphOe\x22\x3e\x3cdiv class\x3d\x22FybcKc\x22\x3e\x3cdiv\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22Xdlr0d\x22\x3e\x3cdiv class\x3d\x22idg8be\x22\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dDune\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLVT9c3NEzLqko2ii8xMBIrTs5MzUtOVUjLTC7JzM9TyM0vy0wtjhJILEssSSxSMDIwsATK5eSeYuTSz9U3SM9NyjZMP8UINabKLMWyIjcZzocae4qRE6Q4KcmkPOcUIweInVWYkQIVNs0tKzJAaCmrqkhKT4Kab1poZlRhDtWTlmSSA9VjllKcnfSLUSwYq3MXsbK4lOal3mKTZDD92MrE8fvpi2NOvhNf8dytkPq-0pfjX3wjABNElPn7AAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAZ\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcQDLLoJlu54amURlfJ2BqQRRyu5IqweG0fZcRVc_g\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eDune\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/a\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dPlanet+of+the+Vampires\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLUz9U3SEoyKc8xEitOzkzNS05VSMtMLsnMz1PIzS_LTC2OEkgsSyxJLFIwMjCwBMrl5J5i5ALpSs9NyjZMP8XIq5-ub2iYVmWWYlmRmwznZ1UlG8WXGJxiRFhxipEDxM4qzEiBCpvmlhUZILSUVVUkpSdBzTctNDOqMIfqSUsyyYHqMUspzk76xSgWjNW5i1jFAnIS81JLFPLTFEoyUhXCEnMLMotSi2-xSTKYfmxl4vj99MUxJ9-Jr3juVkh9X-nL8S--EQBviEjBCQEAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAa\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcTAQN7RLNTf2um9xV5vod7_c9aalK8A5QyJwYENcQ\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3ePlanet of the Vampires\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/a\x3e\x3ca class\x3d\x22BVG0Nb\x22 href\x3d\x22/search?rlz\x3d1C1CHBD_enUS895US895\x26amp;ie\x3dUTF-8\x26amp;q\x3dThe+Day+The+Earth+Stood+Still\x26amp;stick\x3dH4sIAAAAAAAAAOOQUeLQz9U3yCrMSDESK07OTM1LTlVIy0wuyczPU8jNL8tMLY4SSCxLLEksUjAyMLAEyuXknmLkAmlKz03KNkw_xcirn65vaJhWZZZiWZGbDOdnVSUbxZcYnGLkBClOSjIpzznFCLcNKmyaW1ZkgNBSVlWRlJ4ENd-00MyowhyqJy3JJAeqxyylODvpF6NYMFbnLmKVDclIVXBJrFQA0a6JRSUZCsEl-fkpQDIzJ-cWmySD6cdWJo7fT18cc_Kd-IrnboXU95W-HP_iGwE_D1lbDwEAAA\x26amp;sa\x3dX\x26amp;ved\x3d2ahUKEwiWnfa9wun4AhUkZTABHR9kDvIQs9oBegQICRAb\x22\x3e\x3cdiv\x3e\x3cdiv style\x3d\x22width:112px\x22\x3e\x3cdiv class\x3d\x22l7d08\x22 style\x3d\x22width:112px;height:168px\x22\x3e\x3cimg class\x3d\x22h1hFNe\x22 alt\x3d\x22\x22 data-ll\x3d\x22//encrypted-tbn0.gstatic.com/images?q\x3dtbn:ANd9GcQyDRiZF9TcjjDw0nla8ruC9oB92k9KW-wlnErxiw\x26amp;s\x3d0\x22 src\x3d\x22...\x3d\x3d\x22 style\x3d\x22max-width:112px;max-height:168px\x22\x3e\x3c/div\x3e\x3cdiv class\x3d\x22RWuggc kCrYT\x22\x3e\x3cdiv\x3e\x3cdiv class\x3d\x22BNeawe s3v9rd AP7Wnd\x22\x3eThe Day the Earth Stoo...\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x3c/div\x3e\x ...

# %%
subtitle = soup.find('div', class_='XqFnDf')
subtitle

# %%
type(subtitle)
# Out:
# NoneType
