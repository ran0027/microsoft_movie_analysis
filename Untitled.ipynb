# %% [markdown]
# # To Do
# ## Create Notebook Sections
# 1. Import & load statements (move kaggle data to top, with other data)
# 2. Joining data
# 3. Transforming data (changing data types, creating new columns, dropping columns, dealing with missing values)
# 4. Success Metrics
# 5. Recommendation 1 (which genre)
# 6. Recommendation 2 (what time of year)
# 7. Recommendation 3 (which production companies)
# 8. Data used (why this data, and not others)
# 9. Appendix (for cleaning & transforming, analyzing that you ulimately didn't use to answer business questions)
# ## Create Final Data Visualizations
# 1. Bar chart (average revenue & production budget, overlaid, for each genre; order by average revenue; order by average profit)
# 2. Bar chart (average revenue for each part of each month, parts of month overlaid? make sure in order by month)
# - Or, break this out. Make a bar chart of average or total revenue by month. Then make another bar chart breaking out days of the month.
# 3.

# %% [markdown]
# # Import Statements and Load Data

# %%
import pandas as pd
import numpy as np

import sqlite3

from pandasql import sqldf
psdf = lambda x: sqldf(x, globals())

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import json

# %%
conn = sqlite3.connect('Data/im.db')

query = ''' SELECT *
            FROM movie_basics
            JOIN movie_ratings
            USING(movie_id)
            ;'''

imdb_movies = pd.read_sql(query, conn)

imdb_movies.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
tn_movie_budgets = pd.read_csv('rawData/tn.movie_budgets.csv.gz', compression='gzip')

tn_movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
bom_movie_gross = pd.read_csv('rawData/bom.movie_gross.csv.gz', compression='gzip')

bom_movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
kaggle_tmdb_5000 = pd.read_csv('rawData/tmdb_5000_movies.csv.zip')

kaggle_tmdb_5000.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# # Transform Data

# %%
def to_float(value):
    """Takes in a string or float. If string, removes up to 3 commas, 1 $ sign, and whitespace, then converts to float."""
    if type(value) == float:
        return value
    else:
        value = value.replace(',', '')
        value = value.replace(',', '')
        value = value.replace(',', '')
        value = value.replace('$', '')
        value = value.strip()
        return float(value)

# %% [markdown]
# #### Transform budget and revenue columns in tn_movie_budgets (to float)

# %%
tn_movie_budgets['production_budget'] = tn_movie_budgets['production_budget'].map(to_float)

# %%
tn_movie_budgets['domestic_gross'] = tn_movie_budgets['domestic_gross'].map(to_float)

# %%
tn_movie_budgets['worldwide_gross'] = tn_movie_budgets['worldwide_gross'].map(to_float)

# %% [markdown]
# #### Transform bom_movie_gross foreign_gross values (to float)

# %%
bom_movie_gross['foreign_gross'] = bom_movie_gross['foreign_gross'].map(to_float)

# %% [markdown]
# #### Drop one null value for release date in kaggle_tmdb_5000

# %%
kaggle_tmdb_5000.dropna(subset=['release_date'], inplace=True)

# %% [markdown]
# ### Join all data into one table

# %% [markdown]
# #### Make a field called "movie_year" in all tables, to match records by film title and release year

# %%
imdb_movies['movie_year'] = imdb_movies['primary_title'] + ' ' + imdb_movies['start_year'].map(lambda x: str(x))

# %%
tn_movie_budgets['movie_year'] = tn_movie_budgets['movie'] + ' ' + tn_movie_budgets['release_date'].map(lambda x: x[-4:])

# %%
bom_movie_gross['movie_year'] = bom_movie_gross['title'] + ' ' + bom_movie_gross['year'].map(lambda x: str(x))

# %%
kaggle_tmdb_5000['movie_year'] = kaggle_tmdb_5000['original_title'] + ' ' +\
                                kaggle_tmdb_5000['release_date'].map(lambda x: str(x)[:4])

# %% [markdown]
# #### Use pandasql to join the tables on movie_year, and perform an inner join

# %%
query = ''' SELECT t.release_date, t.movie, t.production_budget, t.domestic_gross, t.worldwide_gross,
                    i.primary_title, i.start_year, i.runtime_minutes, i.genres AS imdb_genres,
                    k.genres AS tmdb_genres, k.keywords, k.original_title, k.overview, k.production_companies,
                    k.release_date AS tmdb_release_date, k.runtime AS tmdb_runtime, b.studio, t.movie_year
            FROM tn_movie_budgets as t
            LEFT JOIN imdb_movies as i
            ON i.movie_year = t.movie_year
            LEFT JOIN kaggle_tmdb_5000 as k
            ON i.movie_year = k.movie_year
            LEFT JOIN bom_movie_gross as b
            USING(movie_year)
            WHERE (k.budget IS NOT NULL) | (t.production_budget IS NOT NULL)
            ;
            '''

all_movies = psdf(query)

# %%
all_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5818 entries, 0 to 5817
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   release_date          5818 non-null   object
#  1   movie                 5818 non-null   object
#  2   production_budget     5818 non-null   float64
#  3   domestic_gross        5818 non-null   float64
#  4   worldwide_gross       5818 non-null   float64
#  5   primary_title         1498 non-null   object
#  6   start_year            1498 non-null   float64
#  7   runtime_minutes       1490 non-null   float64
#  8   imdb_genres           1496 non-null   object
#  9   tmdb_genres           977 non-null    object
#  10  keywords              977 non-null    object
#  11  original_title        977 non-null    object
#  12  overview              976 non-null    object
#  13  production_companies  977 non-null    object
#  14  tmdb_release_date     977 non-null    object
# ...

# %% [markdown]
# ### Which genre movie should Microsoft make?

# %%
# find movie(s) for which tmdb_genres has a non-null value, but imdb_genres is null
all_movies.loc[ ~(all_movies['tmdb_genres'].isna()) & (all_movies['imdb_genres'].isna()) ]
# Out:
#       release_date              movie  production_budget  domestic_gross  \
# 1278  Mar 19, 2010  The Bounty Hunter         45000000.0      67061228.0
#
#       worldwide_gross      primary_title  start_year  runtime_minutes  \
# 1278      135808837.0  The Bounty Hunter      2010.0              NaN
#
#      imdb_genres                     tmdb_genres  \
# 1278        None  [{"id": 28, "name": "Action"}]
#
#                                                keywords     original_title  \
# 1278  [{"id": 801, "name": "bounty hunter"}, {"id": ...  The Bounty Hunter
#
#                                                overview  \
# 1278  Milo Boyd is a bounty hunter whose latest gig ...
#
#                                    production_companies tmdb_release_date  \
# 1278  [{"name": "Columbia Pictures", "id": 5}, {"nam...        2010-03-16
#
#       tmdb_runtime studio              movie_year
# 1278         110.0   Sony  The Bounty Hunter 2010

# %%
# since tmdb_genres only adds info for one record, transfer that data to imdb_genres, drop tmdb_genres & rename imdb_genres
# as 'genres'
all_movies.loc[1278, 'imdb_genres'] = 'Action'

all_movies.drop(axis=1, labels='tmdb_genres', inplace=True)

all_movies.rename(columns={'imdb_genres':'genres'}, inplace=True)

# %%
len(all_movies) - len(all_movies.loc[ all_movies.genres.isna() ])
# Out:
# 1497

# %%
# make a copy of movies for genre analysis, and drop records for which genre is null
movies_w_genres = all_movies.copy()

movies_w_genres.dropna(subset=['genres'], inplace=True)

# %%
movies_w_genres.groupby('genres').sum()['worldwide_gross'].sort_values(ascending=False) # max total gross is 34 billion
# Out:
# genres
# Action,Adventure,Sci-Fi       3.420683e+10
# Adventure,Animation,Comedy    2.723296e+10
# Action,Adventure,Fantasy      1.248566e+10
# Action,Adventure,Comedy       8.734515e+09
# Action,Adventure,Animation    7.312483e+09
#                                   ...
# Comedy,Mystery,Thriller       0.000000e+00
# Animation                     0.000000e+00
# Animation,Family              0.000000e+00
# Biography,Documentary         0.000000e+00
# Western                       0.000000e+00
# Name: worldwide_gross, Length: 229, dtype: float64

# %%
np.std(movies_w_genres.groupby('genres').sum()['worldwide_gross']) # standard deviation in total gross is 3.1 billion
# Out:
# 3139667970.9772425

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
with plt.style.context('ggplot'):
    data = movies_w_genres.groupby('genres').sum()['worldwide_gross'].sort_values(ascending=False)[:10]

    centered_labels = [ word.center(26) for word in data.index ]

    centered_labels[9] = 'Comedy '

    fig, ax = plt.subplots(figsize=(12,8))

    bars = ax.bar(centered_labels, data/1000000000)
    
    bars[0].set_color('darkblue')

    for n in [2,3,4]:
        bars[n].set_color('darkblue')
    
    for bar in bars:
        if (bar == bars[0]) | (bar == bars[2]) | (bar == bars[3]) | (bar == bars[4]):
            continue
        else:
            bar.set_color('lightblue')

    ax.set_xticks(range(len(data)))

    ax.set_title('Total Worldwide Gross by Genre', fontsize=20, fontname='Times New Roman')

    ax.set_ylabel('Gross in Billions ($)', fontsize=14, fontname='Times New Roman', labelpad=10)

    [t.set_fontsize(18) for t in ax.yaxis.get_ticklabels()]
    
    [t.set_fontname('Times New Roman') for t in ax.yaxis.get_ticklabels()]

    ax.set_xticklabels(centered_labels,fontsize=14,fontname='Times New Roman')
    
    plt.setp(ax.patches, linewidth=1)

    plt.xticks(rotation=45, ha='right')

    # remove spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    fig.savefig('genres_barplt.png', bbox_inches='tight');

    # bbox = fig.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    # width, height = bbox.width*fig.dpi, bbox.height*fig.dpi
    # height is 2/3 of width;

# %%
with plt.style.context('ggplot'):
    data2 = movies_w_genres.groupby('genres').mean()['worldwide_gross'].sort_values(ascending=False)[:10]

    fig, ax = plt.subplots(figsize=(12,8))

    bars = sns.barplot(data2.index, data2/1000000000, palette='Blues_r', ax=ax)
    
#     bars[0].set_color('darkblue')

#     for n in [2,3,4]:
#         bars[n].set_color('darkblue')
    
#     for bar in bars:
#         if (bar == bars[0]) | (bar == bars[2]) | (bar == bars[3]) | (bar == bars[4]):
#             continue
#         else:
#             bar.set_color('lightblue')

    ax.set_xticks(range(len(data)))

    ax.set_title('Average Worldwide Gross by Genre', fontsize=20, fontname='Times New Roman')

    ax.set_ylabel('Average Gross per Film in Billions ($)', fontsize=14, fontname='Times New Roman', labelpad=10)

    [t.set_fontsize(18) for t in ax.yaxis.get_ticklabels()]
    
    [t.set_fontname('Times New Roman') for t in ax.yaxis.get_ticklabels()]

    ax.set_xticklabels(centered_labels,fontsize=14,fontname='Times New Roman')
    
    plt.setp(ax.patches, linewidth=1)

    plt.xticks(rotation=45, ha='right')

    # remove spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    fig.savefig('genres2_barplt.png', bbox_inches='tight');

    # bbox = fig.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    # width, height = bbox.width*fig.dpi, bbox.height*fig.dpi
    # height is 2/3 of width;
# Out:
# C:\Users\User\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# get the worldwide gross, in BILLIONS, of movie in the top genre, Action/Adventure/Sci-Fi
ww_gross_top_genre = movies_w_genres.loc[ movies_w_genres['genres'] == f'{data.index[0]}' ]['worldwide_gross']/1000000000

fig, ax = plt.subplots(figsize=(10,5))

sns.boxplot(movies_w_genres.loc[ movies_w_genres['genres'] == f'{data.index[0]}' ]['worldwide_gross']/1000000000, ax=ax,\
            palette = 'Blues_r')

ax.set_title('Worldwide Gross of Action/Adventure/Science-Fiction Films', fontsize=18, pad=5)
ax.set_xlabel('Worldwide Gross in Billions ($)', fontsize=12)

# add annotations to highlight quartiles
quart1 = round(ww_gross_top_genre.describe()['25%'],2)
ax.annotate(f'{round(quart1,2)}', xy=(quart1,0), xytext=(quart1-0.05,0.46), backgroundcolor='w')
quart3 = round(ww_gross_top_genre.describe()['75%'], 2)
ax.annotate(f'{round(quart3,2)}', xy=(quart3,0), xytext=(quart3-0.05,0.46), backgroundcolor='w')
med = round(ww_gross_top_genre.describe()['50%'], 2)
ax.annotate(f'{med}', xy=(med,0), xytext=(med-0.05,0.46), backgroundcolor='w')

# add dashed red vertical lines to highlight quartiles
ax.axvline(x=quart1, color='black', linestyle='--', ymin=-0.5, ymax=0.05)
ax.axvline(x=quart3, color='k', linestyle='--', ymin=-0.5, ymax=0.05)
ax.axvline(x=med, color='k', linestyle='--', ymin=-0.5, ymax=0.05)

# make x-axis ticks and labels a little more granular
ax.set_xticks(np.linspace(0,2,21))
ax.set_xticklabels([0.0, '', '', '', '', 0.5, '', '', '', '', 1.0, '', '', '', '', 1.5, '', '', '', '', 2.0])

# don't show the axes spines
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['top'].set_visible(False)

fig.savefig('top_genre_boxplot.png');
# Out:
# C:\Users\User\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# If you are curious about the movie that made zero dollars, look up index 5064 ('Independence Day-saster')

ww_gross_top_genre.loc[ ww_gross_top_genre == ww_gross_top_genre.min() ]
# Out:
# 5064    0.0
# Name: worldwide_gross, dtype: float64

# %%
# average production budget for an action/adventure/science-fiction film is 0.173 billion

all_movies.loc[ww_gross_top_genre.index].mean()['production_budget']
# Out:
# 173161538.46153846

# %%
# get your quartiles for boxplot details

ww_gross_top_genre.describe()
# Out:
# count    52.000000
# mean      0.657824
# std       0.447527
# min       0.000000
# 25%       0.350507
# 50%       0.560914
# 75%       0.868693
# max       2.048134
# Name: worldwide_gross, dtype: float64

# %% [markdown]
# ### Release Date

# %%
movie_dates = all_movies.copy()

movie_dates['release_month'] = movie_dates.release_date.map(lambda x: x[:3])

def part_of_month(value):
    ''' Decide, based on date as string, whether date is early, mid or late in the month.'''
    if int(value[4:6].replace(',','')) < 11:
        return 'early'
    elif int(value[4:6].replace(',','')) < 22:
        return 'mid'
    else:
        return 'late'
    
movie_dates['release_category'] = movie_dates['release_date'].map(part_of_month) +'-' + movie_dates.release_month

# %%
movie_dates.head(3)
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                         None         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# 2                                 Dark Phoenix      2019.0            113.0
#
#                      genres  \
# 0                      None
# 1  Action,Adventure,Fantasy
# 2   Action,Adventure,Sci-Fi
#
#                                             keywords  \
# ...

# %%
data = movie_dates.groupby('release_category').mean()['worldwide_gross'].sort_values(ascending=False)[:5]

# how many movies were released in that release category? overlay as white text annotation on bars
num_movies = [ movie_dates['release_category'].value_counts()[category] for category in data.index ]

fig, ax = plt.subplots(figsize=(10,8))

bars = ax.bar(data.index, data/1000000)

# labels
ax.set(title='Average Gross for a Single Movie Released',xlabel='Release Times',\
       ylabel='Average Gross (in Millions)')

# remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# make y-axis numbers more readable
gross_fmt = mpl.ticker.StrMethodFormatter('${x:,.0f}')
ax.yaxis.set_major_formatter(gross_fmt)
;
# Out:
# ''

# %%
data = movie_dates.groupby('release_category').sum()['worldwide_gross'].sort_values(ascending=False)[:5]

fig, ax = plt.subplots(figsize=(10,8))

num_movies = [ movie_dates['release_category'].value_counts()[category] for category in data.index ]

bars = ax.bar(data.index, data/1000000000)

# labels
ax.set(title='Total Gross for Movies Released during Top 5 Grossing Release Times',xlabel='Release Times',\
       ylabel='Total Gross (in Billions)')

# remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# set opacity of each bar to correspond to number of movies released in that category (in our dataset)
for i in range(len(num_movies)):
    bars[i].set_color((0.6,0.1,0.8, num_movies[i]/max(num_movies)))

# set x- and y- axis colors to match fully opaque bar
ax.spines['left'].set_color((0.6,0.1,0.8, 1))
ax.spines['bottom'].set_color((0.6,0.1,0.8, 1))

# make y-axis numbers more readable
gross_fmt = mpl.ticker.StrMethodFormatter('${x:,.0f}')
ax.yaxis.set_major_formatter(gross_fmt)

# experiment with positioning text more precisely
i = 0
for b in bars:
    # width and height of bar b
    w,h = b.get_width(), b.get_height()
    # lower left vertex
    x0, y0 = b.xy
# annotate with number of movies 0.1 below midpoint of top of bar
    ax.annotate(f'{num_movies[i]}', xy=(0,0), xytext=(x0+w/2-0.085,y0+h-5), color='w', weight='bold')
    i+=1
;
# Out:
# ''

# %% [markdown]
# ### Production Companies

# %%
# Make a copy of all movies, transform production companies column from string-ified json to list of production company
# names, and drop any null values for production companies (given, or resulting from column transformation)

movies_w_production_companies = all_movies.copy()

movies_w_production_companies.dropna(subset=['production_companies'], inplace=True)

def to_list(value):
    if value == '[]':
        return None
    else:
        return [ pc_dict['name'] for pc_dict in json.loads(value) ]
    
movies_w_production_companies['production_companies'] = movies_w_production_companies['production_companies'].map(to_list)

movies_w_production_companies.dropna(subset=['production_companies'], inplace=True)

# %% [markdown]
# - Briefly explore, how many production companies are generally employed to work on a single film?

# %%
movies_w_production_companies.production_companies.map(len).value_counts() # most movies have 5 or less pcs
# Out:
# 3     193
# 4     174
# 2     167
# 1     155
# 5      99
# 6      64
# 7      39
# 8      17
# 9      10
# 11      6
# 10      4
# 19      1
# 17      1
# 15      1
# Name: production_companies, dtype: int64

# %% [markdown]
# Most movies are produced by a group of 5 or less production companies. On the flip side, most films are produced by a group of production companies rather than a solo production company.

# %%
# Add some features to the data

movies_w_production_companies['profit'] = movies_w_production_companies['worldwide_gross']\
                                            - movies_w_production_companies['production_budget']

movies_w_production_companies['roi'] = movies_w_production_companies['profit']\
                                        / movies_w_production_companies['worldwide_gross']

movies_w_production_companies['percentage_of_revenue'] = movies_w_production_companies['worldwide_gross']\
/ movies_w_production_companies['production_companies'].map(len)\
/ movies_w_production_companies['worldwide_gross'].sum()

# %%
# create a new dataframe with one record for each unique movie-production company pair

all_records = []

for index in list(movies_w_production_companies.index):
    # copy record with this index
    current_slice = movies_w_production_companies.loc[index].copy()

    # get a list of production companies for this record
    companies = [ company for company in current_slice['production_companies'] ]

    # how many companies
    n = len(companies)

    # get a copy of the record for each company
    new_records = pd.DataFrame([current_slice]*n).copy()

    # reset production_companies column to have one company per row
    new_records['production_companies'] = companies

    # append your dataframe to the list of dataframes with all records
    all_records.append(new_records)

# concatenate all dataframes!
movies_by_production_companies = pd.concat(all_records).reset_index(drop=True)

# %% [markdown]
# - Find production companies with over 1% of the revenue generated by films. These 16 companies have 35% of the "market share".

# %%
grouped_by_pc = movies_by_production_companies.groupby('production_companies').sum()
print(f'''{len(grouped_by_pc.loc[ grouped_by_pc['percentage_of_revenue'] > 0.01, 'percentage_of_revenue' ])} \
production companies generated \
{grouped_by_pc.loc[ grouped_by_pc['percentage_of_revenue'] > 0.01, 'percentage_of_revenue' ].sum()*100}% \
of the revenue.''')
# Out:
# 16 production companies generated 35.68774073313781% of the revenue.

# %%
# grab the cumulative gross earned by production companies with at least 1% of the "market share" in film-making worldwide
top_pcs_total_gross = grouped_by_pc.loc[ grouped_by_pc['percentage_of_revenue'] > 0.01, 'worldwide_gross' ].\
                    sort_values(ascending=False)
#plot a bar chart of total gross earned by these "top" production companies
fig, ax = plt.subplots()

ax.bar(top_pcs_total_gross.index, top_pcs_total_gross)
plt.xticks(rotation=90);

# %%
grouped_by_pc.index
# Out:
# Index(['10 West Studios', '1019 Entertainment', '10th Hole Productions',
#        '120dB Films', '1492 Pictures', '1821 Pictures',
#        '1984 Private Defense Contractors', '20th Century Fox Russia',
#        '21 Laps Entertainment', '22 & Indiana Pictures',
#        ...
#        'Zanuck Company, The', 'Zapruder Films', 'Zentropa Entertainments',
#        'Zentropa International Köln', 'Zentropa International Sweden',
#        'Zookeeper Productions', 'bob industries', 'thefyzz', 'uFilm',
#        'unafilm'],
#       dtype='object', name='production_companies', length=1429)

# %%
# get the "average profit per film" metric for "top" production companies, in order from highest avg profit to lowest
pcs_by_profit = movies_by_production_companies.groupby('production_companies').mean().loc[top_pcs_total_gross.index,\
                                                                                          'profit'].\
sort_values(ascending=False)

fig, ax = plt.subplots()

ax.bar(pcs_by_profit.index, pcs_by_profit)
plt.xticks(rotation=90);

# %%
fig, ax = plt.subplots()

ax.bar(pcs_by_profit.index, pcs_by_profit)
plt.xticks(rotation=90);

# %%
# for "top" production companies, get avg profit & gross BY YEAR
query = ''' WITH large_production_companies AS (
                                                SELECT production_companies
                                                FROM movies_by_production_companies
                                                GROUP BY production_companies
                                                HAVING SUM(percentage_of_revenue) >= 0.01
                                                )
            SELECT production_companies, start_year, AVG(profit) AS avg_profit, SUM(worldwide_gross) AS gross_per_year
            FROM movies_by_production_companies
            WHERE production_companies IN large_production_companies
            GROUP BY production_companies, start_year
            ;
            '''

pc_over_time = psdf(query)

# %%
# option to expand into new column for data ...
pc_over_time['gross_per_year'].loc[ pc_over_time['production_companies'] == 'Illumination Entertainment' ].cumsum()
# Out:
# 20    5.434646e+08
# 21    7.321222e+08
# 22    1.707339e+09
# 23    2.867675e+09
# 24    3.754426e+09
# Name: gross_per_year, dtype: float64

# %%
# plot gross per year as a line plot with respect to time
data = pc_over_time.loc[ pc_over_time['production_companies'] == 'Illumination Entertainment' ]

fig, ax = plt.subplots()

ax.plot('start_year', 'gross_per_year', data=data, marker='o');

# %% [markdown]
# # End newly organized

# %% [markdown]
# ### Playing with Barplot Styling

# %%
with plt.style.context('seaborn-pastel'):
    data = movies_w_genres.groupby('genres').sum()['worldwide_gross'].sort_values(ascending=False)[:10]

    centered_labels = [ word.center(26) for word in data.index ]

    centered_labels[9] = 'Comedy '

    fig, ax = plt.subplots(figsize=(14,8))

    bars = sns.barplot(centered_labels, data/1000000000)

    ax.set(title='Total Worldwide Gross by Genre', ylabel='Total Worldwide Gross in Billions ($)')

    ax.set_xticks(range(len(data)))
    
    plt.xticks(rotation=45, ha='right')
    
    # color plot background light grey
    ax.set_facecolor('#a9a9a9')
    
    # remove spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    
    # color remaining spines
    ax.spines['left'].set_color('#fff')
    ax.spines['bottom'].set_color('#fff')
    
    # Make label colors for bars match bar colors
    list_of_colors = [patch.get_facecolor() for patch in bars.patches]
    n=0
    for t in ax.xaxis.get_ticklabels():
        t.set_color(list_of_colors[n])
        n+=1
    
    # Make color of tick lines match visible spines
    ax.tick_params(colors='#fff')
    
    # Make color of y-axis tick labels match visible spines
    [t.set_color('#fff') for t in ax.yaxis.get_ticklabels()]
    
    # Make color of y-axis label match visible spines
    ax.yaxis.label.set_color('#fff')
    
    # Make color of title match visible spines
    ax.title.set_color('#fff');

    # bbox = fig.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    # width, height = bbox.width*fig.dpi, bbox.height*fig.dpi
    # height is 2/3 of width;
# Out:
# C:\Users\User\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Create the boxplot for the worldwide gross of films in the top genre in MILLIONS instead of billions

# %%
# Create the boxplot of top genre gross distribution in MILLIONS instead of billions

ww_gross_top_genre = movies_w_genres.loc[ movies_w_genres['genres'] == f'{data.index[0]}' ]['worldwide_gross']/1000000

fig, ax = plt.subplots(figsize=(10,5))

sns.boxplot(movies_w_genres.loc[ movies_w_genres['genres'] == f'{data.index[0]}' ]['worldwide_gross']/1000000, ax=ax,\
            palette = 'Blues_r')

ax.set_title('Worldwide Gross of Action/Adventure/Science-Fiction Films', fontsize=18, pad=5)
ax.set_xlabel('Worldwide Gross in Millions ($)', fontsize=12)

# add annotations to highlight quartiles
quart1 = int(ww_gross_top_genre.describe()['25%'])
ax.annotate(f'{round(quart1,0)}', xy=(quart1,0), xytext=(quart1-0.05,0.46), backgroundcolor='w')
quart3 = int(ww_gross_top_genre.describe()['75%'])
ax.annotate(f'{round(quart3,0)}', xy=(quart3,0), xytext=(quart3-0.05,0.46), backgroundcolor='w')
med = int(ww_gross_top_genre.describe()['50%'])
ax.annotate(f'{med}', xy=(med,0), xytext=(med-0.05,0.46), backgroundcolor='w')

# add dashed red vertical lines to highlight quartiles
ax.axvline(x=quart1, color='black', linestyle='--', ymin=-0.5, ymax=0.05)
ax.axvline(x=quart3, color='k', linestyle='--', ymin=-0.5, ymax=0.05)
ax.axvline(x=med, color='k', linestyle='--', ymin=-0.5, ymax=0.05)

# make x-axis ticks and labels a little more granular
ax.set_xticks(np.linspace(0,2000,21))
ax.set_xticklabels([0.0, '', '', '', '', 500, '', '', '', '', 1000, '', '', '', '', 1500, '', '', '', '', 2000])

# don't show the axes spines
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(True)
ax.spines['top'].set_visible(False);
# Out:
# C:\Users\User\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Play around with making word clouds with keywords from films in the various quartile bands of the top genre

# %%
# Get keywords field in a usable format (string-ified json to list)

def to_list(value):
    if value == '[]':
        return None
    elif value is None:
        return None
    else:
        return [ pc_dict['name'] for pc_dict in json.loads(value) ]
    
movies_w_genres['keywords'] = movies_w_genres['keywords'].map(to_list)

# Make word cloud for bottom 25% of films in top genre

# Find index for each film in bottom 25% of worldwide gross

bottom_quarter_films = ww_gross_top_genre.loc[ ww_gross_top_genre < ww_gross_top_genre.describe()['25%'] ].index

# Loop through key words, and append each word to one long string

text_for_cloud = ''
for list_of_words in movies_w_genres.loc[bottom_quarter_films, 'keywords']:
    if list_of_words is None:
        continue
    else:
        for word in list_of_words:
            text_for_cloud = text_for_cloud + ' "' + word + '"'
            
# Generate word cloud with one long string

from wordcloud import WordCloud

cloud = WordCloud(width=1200, height=800, background_color='white').generate(text_for_cloud)

plt.figure(figsize=(12, 8)) # adjust figsize so that wordcloud can expand to given width & height

plt.imshow(cloud) # show the plot!

plt.axis('off') # don't show axis spines

plt.tick_params(length=0) # don't show tickmarks

# don't show tick labels
plt.xticks([])
plt.yticks([])

plt.savefig('bottom_quarter_wc.png', bbox_inches='tight');

# Repeat for each category (middle 50% of worldwide gross, and top 25% of worldwide gross)

# %%
# Middle 50%

middle_half_films = ww_gross_top_genre.loc[ (ww_gross_top_genre > ww_gross_top_genre.describe()['25%'])\
                                          & (ww_gross_top_genre < ww_gross_top_genre.describe()['75%'])].index

text_for_cloud2 = ''
for list_of_words in movies_w_genres.loc[middle_half_films, 'keywords']:
    if list_of_words is None:
        continue
    else:
        for word in list_of_words:
            text_for_cloud2 = text_for_cloud2 + ' "' + word + '"'

cloud = WordCloud().generate(text_for_cloud2)
plt.imshow(cloud)
plt.tick_params(length=0)
plt.xticks([])
plt.yticks([])
plt.savefig('middle_half_wc.png', bbox_inches='tight');

# %%
# Top 25%

top_quarter_films = ww_gross_top_genre.loc[ ww_gross_top_genre > ww_gross_top_genre.describe()['75%'] ].index

text_for_cloud3 = ''
for list_of_words in movies_w_genres.loc[top_quarter_films, 'keywords']:
    if list_of_words is None:
        continue
    else:
        for word in list_of_words:
            text_for_cloud3 = text_for_cloud3 + ' "' + word + '"'

cloud = WordCloud().generate(text_for_cloud3)
plt.imshow(cloud)
plt.tick_params(length=0)
plt.xticks([])
plt.yticks([])
plt.savefig('top_quarter_wc.png', bbox_inches='tight');

# %%
# Delete

# query = ''' SELECT b.title, t.production_budget, t.domestic_gross, b.foreign_gross, t.worldwide_gross, i.runtime_minutes,
#                     i.genres, b.studio, t.release_date, i.start_year, i.movie_id
#             FROM tn_movie_budgets as t
#             INNER JOIN imdb_movies as i
#             USING(movie_year)
#             INNER JOIN bom_movie_gross as b
#             USING(movie_year)
#             ;
#             '''

# movie_data = psdf(query)

# %% [markdown]
# #### Import directors & writers from imdb database for movies in movie_data

# %%
query = f''' SELECT d.movie_id, d.person_id, p.primary_name
            FROM directors as d
            JOIN persons as p
            USING(person_id)
            WHERE movie_id IN {tuple(preliminary_movie_data['movie_id'].values)}
            ;
            '''
directors = pd.read_sql(query, conn)

directors.head()
# Out:
#     movie_id  person_id        primary_name
# 0  tt1126618  nm0585011       Roger Michell
# 1  tt1336608  nm0788202       Adam Shankman
# 2  tt1336608  nm0788202       Adam Shankman
# 3  tt1336608  nm0788202       Adam Shankman
# 4  tt1341167  nm0606439  Christopher Morris

# %% [markdown]
# Some movie_id and person_id info is duplicated. Drop duplicates.

# %%
directors.drop_duplicates(inplace=True)

# %%
query = f''' SELECT w.movie_id, w.person_id, p.primary_name
            FROM writers as w
            JOIN persons as p
            USING(person_id)
            WHERE movie_id IN {tuple(preliminary_movie_data['movie_id'].values)}
            ;
            '''
writers = pd.read_sql(query, conn)

writers.head()
# Out:
#     movie_id  person_id         primary_name
# 0  tt1126618  nm0112459  Aline Brosh McKenna
# 1  tt1336608  nm0857620       Justin Theroux
# 2  tt1336608  nm0195476      Chris D'Arienzo
# 3  tt1336608  nm1615610           Allan Loeb
# 4  tt1341167  nm0606439   Christopher Morris

# %%
writers.drop_duplicates(inplace=True)

# %%
query = ''' SELECT m.title, m.production_budget, m.domestic_gross, m.foreign_gross, m.worldwide_gross, m.runtime_minutes,
                    m.genres, m.studio,
                    d.primary_name AS director,
                    w.primary_name AS writer,
                    m.release_date, m.start_year,
                    d.person_id AS director_id, w.person_id AS writer_id,
                    m.movie_id
            FROM preliminary_movie_data as m
            JOIN directors as d
            USING(movie_id)
            JOIN writers as w
            USING(movie_id)
            ;
            '''
psdf(query)

# %% [markdown]
# ### Deal with Missing Values

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1043 entries, 0 to 1042
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1043 non-null   object
#  1   production_budget  1043 non-null   float64
#  2   domestic_gross     1043 non-null   float64
#  3   foreign_gross      940 non-null    float64
#  4   worldwide_gross    1043 non-null   float64
#  5   runtime_minutes    1040 non-null   float64
#  6   genres             1042 non-null   object
#  7   studio             1043 non-null   object
#  8   release_date       1043 non-null   object
#  9   start_year         1043 non-null   int64
#  10  movie_id           1043 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 89.8+ KB

# %% [markdown]
# #### Drop 3 records which are missing genres and / or runtime.

# %%
movie_data.dropna(subset=['genres', 'runtime_minutes'], inplace=True)

# %% [markdown]
# #### Inspect missing foreign_gross values.

# %% [markdown]
# The cell below was rerun after filling missing values in the foreign gross column. There are *still* 919 records for which the foreign_gross and domestic_gross do NOT add up to the worldwide_gross. The foreign_gross column comes from the Box Office Mojo dataset, whereas the domestic_gross and worldwide_gross came from The Numbers dataset. This could explain the discrepancy, though I am curious as to why they have different numbers. Is one of them more up to date? Does one of them include only box-office revenue, whereas the other includes DVD sales, selling rights to streaming services, and merchandise related to the film?

# %%
# How many records such that domestic gross + foreign gross NOT = worldwide gross?
len(movie_data.loc[movie_data['domestic_gross'] + movie_data['foreign_gross'] != movie_data['worldwide_gross']])
# Out:
# 919

# %%
movie_data['foreign_gross'].isna().value_counts()
# Out:
# False    937
# True     103
# Name: foreign_gross, dtype: int64

# %% [markdown]
# #### Fill missing foreign_gross values with the difference between the worldwide gross and the domestic gross.

# %%
computed_foreign_gross = movie_data['worldwide_gross'] - movie_data['domestic_gross']

# %%
movie_data['foreign_gross'].fillna(value=computed_foreign_gross, inplace=True)

# %% [markdown]
# ### Add necessary fields to movie_data for analysis

# %%
movie_data['profit'] = movie_data['worldwide_gross'] - movie_data['production_budget']

# %%
movie_data['roi'] = movie_data['profit'] / movie_data['production_budget']

# %%
movie_data.head()
# Out:
#                                          title  production_budget  \
# 0  Pirates of the Caribbean: On Stranger Tides        410600000.0
# 1                      Avengers: Age of Ultron        330600000.0
# 2                       Avengers: Infinity War        300000000.0
# 3                               Justice League        300000000.0
# 4                                      Spectre        300000000.0
#
#    domestic_gross  foreign_gross  worldwide_gross  runtime_minutes  \
# 0     241063875.0    804600000.0     1.045664e+09            136.0
# 1     459005868.0    946400000.0     1.403014e+09            141.0
# 2     678815482.0         1369.5     2.048134e+09            149.0
# 3     229024295.0    428900000.0     6.559452e+08            120.0
# 4     200074175.0    680600000.0     8.796209e+08            148.0
#
#                       genres studio  release_date  start_year   movie_id  \
# 0   Action,Adventure,Fantasy     BV  May 20, 2011        2011  tt1298650
# ...

# %% [markdown]
# # Begin Genre Analysis:
# ### Which genre combinations result in the highest average ROI? What is the standard deviation of the ROI within that group?

# %% [markdown]
# Group the data by genre groups. Find the genre group with the highest average ROI. Also examine the standard deviation of the ROI in that genre group.

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1040 entries, 0 to 1042
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              1040 non-null   object
#  1   production_budget  1040 non-null   float64
#  2   domestic_gross     1040 non-null   float64
#  3   foreign_gross      1040 non-null   float64
#  4   worldwide_gross    1040 non-null   float64
#  5   runtime_minutes    1040 non-null   float64
#  6   genres             1040 non-null   object
#  7   studio             1040 non-null   object
#  8   release_date       1040 non-null   object
#  9   start_year         1040 non-null   int64
#  10  movie_id           1040 non-null   object
#  11  roi                1040 non-null   float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 105.6+ KB

# %% [markdown]
# Find the genre combinations with the highest average return on investment.

# %%
movie_data.groupby('genres').mean()['roi'].sort_values(ascending=False)[:10]
# Out:
# genres
# Horror,Mystery,Thriller    33.874268
# Horror                     28.206820
# Comedy,Documentary         11.930902
# Biography,Drama,Fantasy    11.679440
# Drama,Horror,Mystery       10.851890
# Drama,Horror,Thriller      10.151841
# Comedy,Fantasy              9.463138
# Action,Mystery,Sci-Fi       9.244702
# Drama,Horror,Sci-Fi         9.227946
# Adventure,Drama,Fantasy     8.630940
# Name: roi, dtype: float64

# %%
movie_data.groupby('genres').sum()['profit'].sort_values(ascending=False)[:10]
# Out:
# genres
# Action,Adventure,Sci-Fi       2.202341e+10
# Adventure,Animation,Comedy    1.987871e+10
# Action,Adventure,Fantasy      7.020144e+09
# Action,Adventure,Comedy       5.414946e+09
# Action,Adventure,Animation    4.552758e+09
# Action,Crime,Thriller         3.483001e+09
# Action,Adventure,Thriller     2.679335e+09
# Horror,Mystery,Thriller       2.545909e+09
# Action,Adventure,Drama        2.479634e+09
# Comedy                        2.343395e+09
# Name: profit, dtype: float64

# %% [markdown]
# How many movies of that genre combination are in our dataset?

# %%
movie_data.groupby('genres').count()['title'].loc[list(movie_data.groupby('genres').sum()['profit'].sort_values(ascending=False)[:10].index)]
# Out:
# genres
# Action,Adventure,Sci-Fi       42
# Adventure,Animation,Comedy    60
# Action,Adventure,Fantasy      25
# Action,Adventure,Comedy       15
# Action,Adventure,Animation    12
# Action,Crime,Thriller         16
# Action,Adventure,Thriller     11
# Horror,Mystery,Thriller       24
# Action,Adventure,Drama        21
# Comedy                        36
# Name: title, dtype: int64

# %% [markdown]
# What are the largest sample sizes we have for each genre combination?

# %%
movie_data.groupby('genres').count()['title'].sort_values(ascending=False)[:70]
# Out:
# genres
# Adventure,Animation,Comedy    60
# Comedy,Drama,Romance          43
# Action,Adventure,Sci-Fi       42
# Comedy                        36
# Comedy,Drama                  33
#                               ..
# Action,Comedy,Sci-Fi           4
# Action,Comedy,Romance          4
# Drama,Romance,Sci-Fi           4
# Crime,Thriller                 4
# Crime,Drama,Horror             4
# Name: title, Length: 70, dtype: int64

# %% [markdown]
# Adjust previous grouping and ordering, by limiting the data to only those genre combinations with at least 30 films in the data set.

# %%
query = ''' SELECT genres, COUNT(title) AS num_movies, AVG(roi) AS avg_roi, SUM(profit) AS total_profit
            FROM movie_data
            GROUP BY genres
            HAVING COUNT(title) >= 10
            ORDER BY SUM(profit) DESC
            LIMIT 10
            ;
            '''

psdf(query)
# Out:
#                        genres  num_movies    avg_roi  total_profit
# 0     Action,Adventure,Sci-Fi          42   2.963922  2.202341e+10
# 1  Adventure,Animation,Comedy          60   3.241836  1.987871e+10
# 2    Action,Adventure,Fantasy          25   1.622914  7.020144e+09
# 3     Action,Adventure,Comedy          15   3.639460  5.414946e+09
# 4  Action,Adventure,Animation          12   2.487223  4.552758e+09
# 5       Action,Crime,Thriller          16   1.912078  3.483001e+09
# 6   Action,Adventure,Thriller          11   1.789333  2.679335e+09
# 7     Horror,Mystery,Thriller          24  33.874268  2.545909e+09
# 8      Action,Adventure,Drama          21   1.216688  2.479634e+09
# 9                      Comedy          36   2.332741  2.343395e+09

# %% [markdown]
# The average return on investment for these "top 10" films is much lower than those in the original list, without controlling for sample size. Let's investigate 'Horror, Mystery, Thriller' from the original top 10 list, which is getting *close* to the min sample size of 30, along with the top 10 generated by controlling for sample size.

# %% [markdown]
# # Get more data! Bring in the TMDB 5000 dataset from Kaggle
#
# Kaggle dataset: https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata?resource=download&select=tmdb_5000_movies.csv

# %% [markdown]
# # Return to genre analysis
# Now that we have more data, let's see how many genre combinations have at least 30 films in the sample.

# %%
all_movies.groupby('genres').count()['movie'].sort_values(ascending=False)
# Out:
# genres
# Adventure,Animation,Comedy    67
# Drama                         57
# Comedy                        56
# Action,Adventure,Sci-Fi       52
# Comedy,Drama,Romance          51
#                               ..
# Comedy,Horror,Mystery          1
# Comedy,Horror,Sci-Fi           1
# Comedy,Music,War               1
# Comedy,Mystery,Sci-Fi          1
# Comedy,Crime,Romance           1
# Name: movie, Length: 229, dtype: int64

# %%
query = ''' SELECT genres, COUNT(*) AS num_movies, AVG(roi) AS avg_roi, SUM(profit) AS total_profit
            FROM all_movies
            GROUP BY genres
            HAVING COUNT(*) >= 30
            ORDER BY SUM(profit) DESC
            ;
            '''
psdf(query)
# Out:
#                         genres  num_movies    avg_roi  total_profit
# 0                         None        4321   4.171000  2.029934e+11
# 1      Action,Adventure,Sci-Fi          52   2.734575  2.520243e+10
# 2   Adventure,Animation,Comedy          67   2.983651  2.034746e+10
# 3     Action,Adventure,Fantasy          31   1.494635  7.840060e+09
# 4      Horror,Mystery,Thriller          31  27.524288  2.963063e+09
# 5                       Comedy          56   1.342571  2.436345e+09
# 6               Comedy,Romance          41   2.173336  2.271748e+09
# 7                Drama,Romance          34   3.823069  1.914878e+09
# 8          Action,Comedy,Crime          31   1.469341  1.784277e+09
# 9                 Comedy,Drama          48   2.128621  1.449442e+09
# 10        Comedy,Drama,Romance          51   2.188463  1.436224e+09
# 11          Action,Crime,Drama          39   1.006888  1.009424e+09
# 12                       Drama          57   2.173775  7.257196e+08

# %% [markdown]
# I want to see a boxplot of the return on investment for movies in the "Horror, Mystery, Thriller" genre in this dataset.

# %%
hmt_roi = all_movies.loc[ all_movies['genres'] == 'Horror,Mystery,Thriller' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(hmt_roi);

# %%
query = ''' SELECT primary_title, movie, roi, genres, release_date
            FROM all_movies
            WHERE roi > 400
            ;
            '''
psdf(query)
# Out:
#   primary_title                    movie          roi  \
# 0          None  The Blair Witch Project   412.833333
# 1          None      Paranormal Activity   430.517853
# 2          None                  Mad Max   497.750000
# 3   The Gallows              The Gallows   415.564740
# 4          None              Deep Throat  1799.000000
#
#                     genres  release_date
# 0                     None  Jul 14, 1999
# 1                     None  Sep 25, 2009
# 2                     None  Mar 21, 1980
# 3  Horror,Mystery,Thriller  Jul 10, 2015
# 4                     None  Jun 30, 1972

# %%
fig, ax = plt.subplots()

ax.boxplot(hmt_roi, showfliers=False);

# %%
dr_roi = all_movies.loc[ all_movies['genres'] == 'Drama,Romance' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(dr_roi);

# %%
aac_roi = all_movies.loc[ all_movies['genres'] == 'Adventure,Animation,Comedy' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(aac_roi);

# %%
aas_roi = all_movies.loc[ all_movies['genres'] == 'Action,Adventure,Sci-Fi' ]['roi']

# %%
fig, ax = plt.subplots()

ax.boxplot(aas_roi);

# %% [markdown]
# # Try scraping google search results for genre

# %% [markdown]
# 1. Iterate through titles of movies which don't currently have a genre or genres listed. (i.e. all_movies.movie.values for which all_movies.genres.isna() )
# 2. Split the movie title on spaces, then concatenate separated by +s. Then concatenate with string 'www.google.com/search?q=' on the left, and '+film+' + str(year in which film was released.)
# 3. Pass this URL to beautiful soup! I am going to pass a particular URL to beautiful soup below to be sure that I can extract the genre from the page successfully, before working to construct the loop to scrape many sites.

# %%
from bs4 import BeautifulSoup
import requests

# %%
# html_page = requests.get('https://www.google.com/search?q=avatar+2009+film')
# html_page = requests.get('https://www.google.com/search?q=avatar+2009+film&rlz=1C1CHBD_enUS895US895&oq=avat&aqs=chrome.0.69i59j69i57j46i67i433j46i67i131i433j46i67i433j69i60l3.1108j0j7&sourceid=chrome&ie=UTF-8')
# html_page = requests.get('https://www.google.com/search?=avatar+2009+film/setprefs?hl=en&prev=https://www.google.com/search?q%3Davatar%2B2009%2Bfilm%26pccc%3D1&sig=0_ywSwDDzyYvjVgQe2sFltYzXF1qk%3D&cs=2')
html_page = requests.get('https://www.google.com/search?=avatar+2009+film')
soup = BeautifulSoup(html_page.content, 'html5lib') # I tried the first 3 URLs with 'html.parser'

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
subtitle = soup.find('div', class_='XqFnDf')
subtitle

# %%
type(subtitle)
# Out:
# NoneType

# %% [markdown]
# # Scraping did not work; try manually

# %%
all_movies.head(2)
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                         None         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
#
#                      genres  \
# 0                      None
# 1  Action,Adventure,Fantasy
#
#                                             keywords  \
# 0                                               None
# 1  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
#
#                                 original_title  \
# 0                                         None
# ...

# %%
# quick test
# you would loop through each movie in the list of movies with no genres
# for that movie, keep a count
movie_yr = 'Avatar 2009'
count = 1
genres=''
first_genre = input(f'Genre 1 for {movie_yr}: ')
print('When no additional genres exist, press enter.')
genres = first_genre+','+input(f'Genre {count + 1} for {movie_yr}:' )
count += 1
genres
# Out:
# Genre 1 for Avatar 2009: Action
# When no additional genres exist, press enter.
# Genre 2 for Avatar 2009:Science-Fiction
# 'Action,Science-Fiction'

# %%
user_input = 1
while user_input != '0':
    user_input = input(f'Genre: :' )
# Out:
# Genre: :Action
# Genre: :Science-Fiction
# Genre: :Fantasy
# Genre: :0

# %%
# loop through each movie_year for movies with no genres
# for that movie, you will have a value for movie_year, e.g.
films = ['Avatar 2009', 'Pirates of the Caribbean 2011']
for film in films:
    print(film+'\n')
    print('To skip, or to finish entering genres, press enter.')
    first_genre = input(f'First genre for {film}:' )
    if first_genre == '':
        continue
    else:
        genres = first_genre
    flag = True
    while flag:
        next_genre = input(f'Next genre for {movie_yr} with genres: {genres}\n')
        if next_genre == '':
            flag = False
        else:
            genres = genres + ',' + next_genre
    print('\n\n')
    # Need to append genres to appropriate spot
# Out:
# Avatar 2009
#
# To skip, or to finish entering genres, press enter.
# First genre for Avatar 2009:Action
# Next genre for Avatar 2009 with genres: Action
# Fantasy
# Next genre for Avatar 2009 with genres: Action,Fantasy
#
#
#
#
# Pirates of the Caribbean 2011
#
# To skip, or to finish entering genres, press enter.
# First genre for Pirates of the Caribbean 2011:

# %%
all_movies.loc[ all_movies['genres'].isna() ]
# Out:
#       release_date                                       movie  \
# 0     Dec 18, 2009                                      Avatar
# 4     Dec 15, 2017           Star Wars Ep. VIII: The Last Jedi
# 5     Dec 18, 2015        Star Wars Ep. VII: The Force Awakens
# 7     May 24, 2007  Pirates of the Caribbean: At Worldâs End
# 15     May 4, 2007                                Spider-Man 3
# ...            ...                                         ...
# 5813  Dec 31, 2018                                      Red 11
# 5814   Apr 2, 1999                                   Following
# 5815  Jul 13, 2005               Return to the Land of Wonders
# 5816  Sep 29, 2015                        A Plague So Pleasant
# 5817   Aug 5, 2005                           My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross primary_title  \
# 0           425000000.0     760507625.0     2.776345e+09          None
# ...

# %%
idx_no_genres = list(all_movies.index[ all_movies['genres'].isna() ])

# %%
all_movies.loc[5813]
# Out:
# release_date            Dec 31, 2018
# movie                         Red 11
# production_budget               7000
# domestic_gross                     0
# worldwide_gross                    0
# primary_title                   None
# start_year                       NaN
# runtime_minutes                  NaN
# genres                          None
# keywords                        None
# original_title                  None
# overview                        None
# production_companies            None
# tmdb_release_date               None
# tmdb_runtime                     NaN
# studio                          None
# movie_year               Red 11 2018
# roi                               -1
# Name: 5813, dtype: object

# %%
for idx in idx_no_genres:
    all_movies.loc[idx, 'genres']
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
all_movies['production_companies'].loc[1]
# Out:
# '[{"name": "Walt Disney Pictures", "id": 2}, {"name": "Jerry Bruckheimer Films", "id": 130}, {"name": "Moving Picture Company (MPC)", "id": 20478}]'

# %%
import json
x = json.loads(all_movies['production_companies'].loc[1])

# %%
x
# Out:
# [{'name': 'Walt Disney Pictures', 'id': 2},
#  {'name': 'Jerry Bruckheimer Films', 'id': 130},
#  {'name': 'Moving Picture Company (MPC)', 'id': 20478}]

# %%
type(x)
# Out:
# list

# %%
x[0]['name']
# Out:
# 'Walt Disney Pictures'

# %% [markdown]
# # Save all_movies as csv

# %%
all_movies.to_csv('processedData/all_movies.csv', index=False)

# %% [markdown]
# #### Begin the herculean task of adding genres manually where they are lacking

# %%
idx_no_genres = list(all_movies.index[ all_movies['genres'].isna() ])

# %%
for idx in idx_no_genres:
    film = all_movies.loc[idx, 'movie_year']
    
    print(film+'\n') # Print movie title, so I know what genres to look up
    print('To skip, or to finish entering genres, press enter.') # Remember how to continue to next movie when done
    print('To get more information about the film, press 2.') # in case 2 films same name same year, need to discern
    
    first_genre = input(f'First genre for { film }:' ) # Get the first genre, if there is one
    
    if first_genre == '':
        continue
    elif first_genre == '2':
        print(all_movies.loc[idx]+'\n')
    else:
        genres = first_genre
    
    flag = True
    while flag: # Prompt for more genres
        next_genre = input(f'Next genre for { film } with genres: {genres}\n')
        if next_genre == '':
            flag = False
        elif next_genre == '2':
            print(all_movies.loc[idx]+'\n')
        else:
            genres = genres + ',' + next_genre
    print('\n\n')
    
    all_movies.loc[idx, 'genres'] = genres # actually save genres to dataframe when done creating string!
# Out:
# Avatar 2009
#
# To skip, or to finish entering genres, press enter.
# To get more information about the film, press 2.
# First genre for Avatar 2009:Action
# Next genre for Avatar 2009 with genres: Action
# Science-Fiction
# Next genre for Avatar 2009 with genres: Action,Science-Fiction
#
#
#
#
# Star Wars Ep. VIII: The Last Jedi 2017
#
# To skip, or to finish entering genres, press enter.
# To get more information about the film, press 2.
# First genre for Star Wars Ep. VIII: The Last Jedi 2017:Action
# Next genre for Star Wars Ep. VIII: The Last Jedi 2017 with genres: Action
# Science-Fiction
# Next genre for Star Wars Ep. VIII: The Last Jedi 2017 with genres: Action,Science-Fiction
#
#
#
#
# Star Wars Ep. VII: The Force Awakens 2015
#
# To skip, or to finish entering genres, press enter.
# To get more information about the film, press 2.
# First genre for Star Wars Ep. VII: The Force Awakens 2015:Adventure
# ...

# %%
all_movies.genres.isna().value_counts()
# Out:
# True     4126
# False    1692
# Name: genres, dtype: int64

# %% [markdown]
# Save progress so far to .csv!

# %%
all_movies.to_csv('processedData/all_movies_updated.csv', index=False)

# %% [markdown]
# #### Genres to go back and fix

# %%
# movie = 'Alexander 2004' - change WAr, to War, in genres
# movie = 'Kingdom of Heaven 2005' - change war to War, in genres
# movie = 'Ali 2001' - change 'Historical-Drama', to 'Historical', in genres??
# movie = 'Jin lÃ­ng shÃ­ san chai 2012' - listed Drama, Historical, separately! (Should I use "History" instead??)
# movie = 'Robin Hood 2018' - change Adventurue to Adventure, in genres
# movie = 'Black Hawk Down 2001' - used History, not Historical, in genres

# %% [markdown]
# # Look at studios / production companies

# %%
movies = pd.read_csv('processedData/all_movies.csv')

# %%
movies.head()
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                          NaN         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# ...

# %% [markdown]
# #### Transform production_companies field: reformat string-ified JSON to list
# The null values appear to be considered type float, so I created a custom function to check whether the value is a string or float before converting to json, then looping through the list of dictionaries and pulling only the name of the production company to store in a list

# %%
import json

def to_json(value):
    ''' If the type of the value is string, convert to json & make a list of names of studios in the json. '''
    if type(value) is str:
        as_a_json = json.loads(value)
        return [ studio_dict['name'] for studio_dict in as_a_json ]
    else:
        return value

# %%
movies['production_companies'] = movies.production_companies.map(to_json)

# %% [markdown]
# #### Examine the correlation between fields in the movies dataframe

# %%
movies.corr()['profit']
# Out:
# production_budget    0.610426
# domestic_gross       0.926768
# worldwide_gross      0.981898
# start_year           0.090000
# runtime_minutes      0.283616
# tmdb_runtime         0.285099
# profit               1.000000
# roi                  0.070385
# Name: profit, dtype: float64

# %%
# Create a seaborn heatmap to show correlations
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(movies.corr(), center=0, cmap='coolwarm', robust=True, annot=True);

# %% [markdown]
# #### Make a copy of movies dataframe in case I mess this up =)

# %%
production_company_analysis = movies.copy()

# %%
# Drop records without a production company
production_company_analysis.dropna(subset=['production_companies'], inplace=True)

# %%
production_company_analysis['num_production_companies']\
= production_company_analysis['production_companies'].map(lambda x: len(x))

# %%
no_production_companies\
= production_company_analysis.loc[ production_company_analysis['num_production_companies'] == 0 ].index

# %%
production_company_analysis.drop(no_production_companies, inplace=True)

# %%
production_company_analysis.head(4)
# Out:
#     release_date                                        movie  \
# 1   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    May 1, 2015                      Avengers: Age of Ultron
# 9    Nov 6, 2015                                      Spectre
# 10  Jul 20, 2012                        The Dark Knight Rises
#
#     production_budget  domestic_gross  worldwide_gross  \
# 1         410600000.0     241063875.0     1.045664e+09
# 3         330600000.0     459005868.0     1.403014e+09
# 9         300000000.0     200074175.0     8.796209e+08
# 10        275000000.0     448139099.0     1.084439e+09
#
#                                   primary_title  start_year  runtime_minutes  \
# 1   Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# 3                       Avengers: Age of Ultron      2015.0            141.0
# 9                                       Spectre      2015.0            148.0
# ...

# %%
production_company_analysis['percentage_of_revenue'] = production_company_analysis['worldwide_gross']\
/ production_company_analysis['production_companies'].map(len)\
/ production_company_analysis['worldwide_gross'].sum()

# %%
production_company_analysis.head(2)
# Out:
#    release_date                                        movie  \
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3   May 1, 2015                      Avengers: Age of Ultron
#
#    production_budget  domestic_gross  worldwide_gross  \
# 1        410600000.0     241063875.0     1.045664e+09
# 3        330600000.0     459005868.0     1.403014e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# 3                      Avengers: Age of Ultron      2015.0            141.0
#
#                      genres  \
# 1  Action,Adventure,Fantasy
# 3   Action,Adventure,Sci-Fi
#
#                                             keywords  ...  \
# 1  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...  ...
# 3  [{"id": 8828, "name": "marvel comic"}, {"id": ...  ...
#
#                                             overview  \
# 1  Captain Jack Sparrow crosses paths with a woma...
# ...

# %%
production_company_analysis['percentage_of_revenue'].sum()
# Out:
# 0.37542303786199765

# %% [markdown]
# #### Prepare data for an analysis of production companies
# For each record in production_company_analysis, make n copies of that record, where n = the number of production companies in the production_companies field, then overwrite the production_companies list in each repeated record with a single unique production company that worked on that film. Add these records to a list of dataframes. After iterating through all records in production_company_analysis, concatenate the list of duplicated records.

# %%
# make a list of dataframes like the above, then concatenate at the end

all_records = []

for index in list(production_company_analysis.index):
    # copy record with this index
    current_slice = production_company_analysis.loc[index].copy()

    # get a list of production companies for this record
    companies = [ company for company in current_slice['production_companies'] ]

    # how many companies
    n = len(companies)

    # get a copy of the record for each company
    new_records = pd.DataFrame([current_slice]*n).copy()

    # reset production_companies column to have one company per row
    new_records['production_companies'] = companies

    # append your dataframe to the list of dataframes with all records
    all_records.append(new_records)

# concatenate all dataframes!
movies_by_production_companies = pd.concat(all_records).reset_index(drop=True)

# %%
movies_by_production_companies['percentage_of_revenue'].sum()
# Out:
# 1.0

# %%
movies_by_production_companies.groupby('production_companies').sum()['percentage_of_revenue'].sort_values(ascending=False)
# Out:
# production_companies
# Marvel Studios          0.043414
# Walt Disney Pictures    0.040045
# Columbia Pictures       0.035958
# Universal Pictures      0.034378
# DreamWorks Animation    0.034313
#                           ...
# Rapid Heart Pictures    0.000000
# New Kingdom Pictures    0.000000
# Sunrise Productions     0.000000
# The Klimax              0.000000
# Spy Global Media        0.000000
# Name: percentage_of_revenue, Length: 1429, dtype: float64

# %%
data = movies_by_production_companies.groupby('production_companies').sum()['percentage_of_revenue'].sort_values(ascending=False)[:30]

fig, ax = plt.subplots()

ax.bar(x=np.linspace(0,1,30), width=1/30, height=data.values, label=data.index);

# %% [markdown]
# #### Look at distribution of production_companies for top 10

# %%
data = movies_by_production_companies.production_companies.value_counts()[:10]

# %% [markdown]
# Should I try to determine how much production company influences the success of the film? For example, can I "normalize" the worldwide gross generated by each company? (i.e. take the gross for the film, divide by the number of production companies that worked on it, and then divide that portion by the sum of all worldwide gross from films?)

# %% [markdown]
# #### Tickmark rotation:
# change 'Twentieth Century Fox Film Corporation' to '20th Century Fox Film Corp', then pad all labels with whitespace so that they have the same length, and rotate 60 degrees (J pointed out that the center of rotation is the middle of the string xD instead of the end)

# %%
fig, ax = plt.subplots()

ax.bar(data.index, data)
plt.xticks(rotation=90);

# %% [markdown]
# #### Find the average number of production companies per film

# %%
query = ''' WITH accessory_table AS
                                    (SELECT COUNT(*) AS num_production_companies
                                    FROM movies_by_production_companies
                                    GROUP BY movie_year)
            
            SELECT AVG(num_production_companies)
            FROM accessory_table
            ;
            '''

psdf(query)
# Out:
#    AVG(num_production_companies)
# 0                       3.617325

# %% [markdown]
# #### Look at top 5 production companies with highest total profit (to date)

# %%
profit_data = movies_by_production_companies.groupby('production_companies').sum()['profit'].sort_values(ascending=False)[:5]

# %%
fig, ax = plt.subplots()

ax.bar(profit_data.index, profit_data.values)
plt.xticks(rotation=90);

# %%
profit_data['Universal Pictures'] - profit_data['Walt Disney Pictures'] # just wondering how big universal's lead is
# Out:
# 1795816184.0

# %%
np.mean(profit_data) # what is the average profit to date?
# Out:
# 9918583541.8

# %% [markdown]
# #### Find top 5 production companies by average profit

# %%
avg_profit_data = movies_by_production_companies.groupby('production_companies').mean()['profit'].sort_values(ascending=False)[:5]

# %%
fig, ax = plt.subplots()

ax.bar(avg_profit_data.index, avg_profit_data.values)
plt.xticks(rotation=90);

# %% [markdown]
# #### Select top 10 production companies (who have made more than 5 films) by average profit; also list total profit

# %%
query = ''' SELECT production_companies, AVG(profit) AS avg_profit, SUM(profit) AS total_profit
            FROM movies_by_production_companies
            GROUP BY production_companies
            HAVING COUNT(*) > 5
            ORDER BY AVG(profit) DESC
            LIMIT 10
            ;
            '''

psdf(query)
# Out:
#             production_companies    avg_profit  total_profit
# 0                 Marvel Studios  6.618722e+08  7.280595e+09
# 1        Fuji Television Network  6.548324e+08  3.928994e+09
# 2         Revolution Sun Studios  5.662055e+08  3.397233e+09
# 3        Pixar Animation Studios  4.946228e+08  2.967737e+09
# 4                         Dentsu  4.124934e+08  4.124934e+09
# 5           Marvel Entertainment  3.911472e+08  2.738031e+09
# 6                     Roth Films  3.629341e+08  2.540539e+09
# 7  Walt Disney Animation Studios  3.628803e+08  2.177282e+09
# 8               DC Entertainment  3.604151e+08  2.522905e+09
# 9           Amblin Entertainment  3.479374e+08  3.827312e+09

# %% [markdown]
# #### Select top 10 production companies (who have made more than 5 films) by total profit; also list average profit

# %%
query = ''' SELECT production_companies, AVG(profit) AS avg_profit, SUM(profit) AS total_profit
            FROM movies_by_production_companies
            GROUP BY production_companies
            HAVING COUNT(*) > 5
            ORDER BY SUM(profit) DESC
            LIMIT 10
            ;
            '''

psdf(query)
# Out:
#                      production_companies    avg_profit  total_profit
# 0                      Universal Pictures  1.583223e+08  1.155753e+10
# 1                    Walt Disney Pictures  3.050535e+08  9.761712e+09
# 2                            Warner Bros.  1.624710e+08  9.585788e+09
# 3                       Columbia Pictures  1.687333e+08  9.449065e+09
# 4                      Paramount Pictures  1.965707e+08  9.238824e+09
# 5  Twentieth Century Fox Film Corporation  1.890168e+08  7.371654e+09
# 6                          Marvel Studios  6.618722e+08  7.280595e+09
# 7                      Legendary Pictures  2.882733e+08  6.342013e+09
# 8                       TSG Entertainment  2.347990e+08  5.869976e+09
# 9                         New Line Cinema  1.748197e+08  5.594231e+09

# %% [markdown]
# #### Plot time vs profit for top production company by total profit to date; also plot time vs budget (not helpful, but can I do something different with this idea?)
# My idea is to analyze the **optimal production budget** to *maximize profit*, if size of production budget is correlated in some way with profit.

# %%
query = ''' SELECT start_year, profit, production_budget
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures'
            ORDER BY start_year
            ;
            '''

universal_year_profit = psdf(query)

query = ''' SELECT start_year, production_budget
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures'
            ORDER BY start_year
            ;
            '''

universal_year_budget = psdf(query)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10, 8))

ax[0].scatter(universal_year_profit.start_year.values, universal_year_profit.profit.values,\
             c=universal_year_profit.production_budget, cmap='Purples')

ax[1].scatter(universal_year_budget.start_year.values, universal_year_budget.production_budget.values);

# Later: change the size / color of the dot based on size & sign (+ or -) of profit

# %% [markdown]
# #### Plot time vs profit for top production company by average profit per film to date

# %%
query = ''' SELECT start_year, profit, production_budget
            FROM movies_by_production_companies
            WHERE production_companies = 'Marvel Studios'
            ORDER BY start_year
            ;
            '''

marvel_year_profit = psdf(query)

# %%
fig, ax = plt.subplots()

ax.scatter(marvel_year_profit.start_year.values, marvel_year_profit.profit.values,\
          c=marvel_year_profit.production_budget, cmap='Purples');

# %% [markdown]
# Calculate the average production budget for Universal films with positive roi vs. for Universal films with negative roi.

# %%
query = ''' SELECT AVG(production_budget) AS avg_budget_positive_roi
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures' AND roi > 0
            ;
            '''

psdf(query)
# Out:
#    avg_budget_positive_roi
# 0             5.293485e+07

# %%
query = ''' SELECT AVG(production_budget) AS avg_budget_negative_roi
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures' AND roi < 0
            ;
            '''

psdf(query)
# Out:
#    avg_budget_negative_roi
# 0             8.171429e+07

# %%
query = ''' SELECT production_budget, profit
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures'
            ;
            '''

universal_budget_profit = psdf(query)

# %%
fig, ax = plt.subplots()

ax.scatter(universal_budget_profit.production_budget.values, universal_budget_profit.profit.values)
ax.set_xlabel('Production Budget')
ax.set_ylabel('Profit')
ax.set_title('Production Budget and Profit for Universal Films')
fig.tight_layout();

# %%
query = ''' SELECT production_budget, profit
            FROM movies_by_production_companies
            WHERE production_companies = 'Marvel Studios'
            ;
            '''

marvel_budget_profit = psdf(query)

# %%
fig, ax = plt.subplots()

ax.scatter(marvel_budget_profit.production_budget.values, marvel_budget_profit.profit.values)
ax.set_xlabel('Production Budget')
ax.set_ylabel('Profit')
ax.set_title('Production Budget and Profit for Marvel Studios Films')
fig.tight_layout();

# %%
query = ''' SELECT start_year, COUNT()
            FROM movies_by_production_companies
            WHERE production_companies = 'Universal Pictures'
            GROUP BY start_year
            ;
            '''

psdf(query)
# Out:
#    start_year  COUNT()
# 0      2010.0       11
# 1      2011.0       12
# 2      2012.0       10
# 3      2013.0        9
# 4      2014.0        9
# 5      2015.0       13
# 6      2016.0        9

# %%
query = ''' SELECT start_year, COUNT()
            FROM movies_by_production_companies
            WHERE production_companies = 'Marvel Studios'
            GROUP BY start_year
            ;
            '''

psdf(query)
# Out:
#    start_year  COUNT()
# 0      2010.0        1
# 1      2011.0        2
# 2      2012.0        1
# 3      2013.0        2
# 4      2014.0        2
# 5      2015.0        2
# 6      2016.0        1

# %%
movies.head()
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   Jun 7, 2019                                 Dark Phoenix
# 3   May 1, 2015                      Avengers: Age of Ultron
# 4  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                          NaN         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
# ...

# %%
movies.loc[ movies['roi'] > 0 ].mean()
# Out:
# production_budget    3.844694e+07
# domestic_gross       6.250517e+07
# worldwide_gross      1.389393e+08
# start_year           2.013872e+03
# runtime_minutes      1.095363e+02
# tmdb_runtime         1.092034e+02
# roi                  6.374600e+00
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(14,10))

ax.scatter(movies['production_budget'], movies['roi'], c=movies['profit'], cmap='viridis', alpha=0.5);

# %%
movies.loc[ movies['roi'] < 0 ].mean()
# Out:
# production_budget    1.981061e+07
# domestic_gross       6.208691e+06
# worldwide_gross      9.823493e+06
# start_year           2.013780e+03
# runtime_minutes      1.024009e+02
# tmdb_runtime         9.840520e+01
# roi                 -6.729734e-01
# dtype: float64

# %%
fig, ax = plt.subplots()

ax.hist(movies.loc[ movies['roi'] > 0 ]['production_budget'], bins=20);

ax.hist(movies.loc[ movies['roi'] < 0 ]['production_budget'], bins=20, color='r');

# %%
movies.groupby('studio').mean()['worldwide_gross'].sort_values(ascending=False)
# Out:
# studio
# P/DW        5.078028e+08
# BV          4.669045e+08
# GrtIndia    2.635029e+08
# Fox         2.427769e+08
# Sony        2.384703e+08
#                 ...
# Alc         1.610970e+05
# IVP         1.026450e+05
# KE          9.495300e+04
# First       8.552700e+04
# BBC         7.943000e+03
# Name: worldwide_gross, Length: 96, dtype: float64

# %%
movies_by_production_companies['count'] = [1]*len(movies_by_production_companies)

# %%
movies_by_production_companies.loc[ movies['studio'] == 'P/DW' ].groupby('production_companies').sum()['count']
# Out:
# production_companies
# Atlas Entertainment                     1
# Dentsu                                  1
# Lions Gate Films                        1
# Media Rights Capital (MRC)              1
# Moving Picture Company (MPC)            1
# One Race Films                          1
# Syncopy                                 1
# Village Roadshow Films North America    1
# Warner Bros.                            1
# Zookeeper Productions                   1
# Name: count, dtype: int64

# %%
movies_by_production_companies.loc[ movies['studio'] == 'BV' ].groupby('production_companies').sum()['count']
# Out:
# production_companies
# 3Foot7                                    1
# Abu Dhabi Film Commission                 1
# Broken Road Productions                   1
# Chernin Entertainment                     1
# China Film Co.                            1
# Ciné+                                     1
# Columbia Pictures                         2
# DC Comics                                 1
# DC Entertainment                          1
# DMG Entertainment                         1
# Dentsu                                    1
# Di Bonaventura Pictures                   1
# Down Productions                          1
# Echo Films                                1
# Entertainment One                         1
# Fox 2000 Pictures                         1
# Fox Searchlight Pictures                  1
# Goldenlight Films                         1
# Hasbro                                    2
# Hasbro Studios                            1
# Holleran Company                          1
# ...

# %% [markdown]
# # What time of year should our movie be released?

# %%
movies.head(2)
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                          NaN         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
#
#                      genres  \
# 0                       NaN
# 1  Action,Adventure,Fantasy
#
#                                             keywords  \
# 0                                                NaN
# 1  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
#
#                                 original_title  \
# 0                                          NaN
# ...

# %%
movies['release_date'][0][:7].replace(',', '').strip()
# Out:
# 'Dec 18'

# %%
movies['release_month'] = movies.release_date.map(lambda x: x[:3])

# %%
movies.head(2)
# Out:
#    release_date                                        movie  \
# 0  Dec 18, 2009                                       Avatar
# 1  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
#
#    production_budget  domestic_gross  worldwide_gross  \
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
#
#                                  primary_title  start_year  runtime_minutes  \
# 0                                          NaN         NaN              NaN
# 1  Pirates of the Caribbean: On Stranger Tides      2011.0            136.0
#
#                      genres  \
# 0                       NaN
# 1  Action,Adventure,Fantasy
#
#                                             keywords  \
# 0                                                NaN
# 1  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...
#
#                                 original_title  \
# 0                                          NaN
# ...

# %%
movies['release_month'] = movies.release_date.map(lambda x: x[:3])

def part_of_month(value):
    ''' Decide, based on date as string, whether date is early, mid or late in the month.'''
    if int(value[4:6].replace(',','')) < 11:
        return 'early'
    elif int(value[4:6].replace(',','')) < 22:
        return 'mid'
    else:
        return 'late'
    
movies['release_category'] = movies['release_date'].map(part_of_month) +'-' + movies.release_month

# %%
movies['release_date'].map(part_of_month)
# Out:
# mid      2178
# late     1938
# early    1702
# Name: release_date, dtype: int64

# %%
movies['release_category'] = movies['release_date'].map(part_of_month) +'-' + movies.release_month

# %%
movies['release_category'].value_counts()
# Out:
# late-Dec     370
# mid-Dec      257
# mid-Oct      215
# mid-Nov      211
# early-Oct    199
# mid-Aug      189
# mid-Sep      187
# late-Sep     184
# mid-Jun      183
# mid-Mar      178
# mid-Jul      168
# late-Jun     162
# early-Nov    160
# late-Oct     160
# early-Aug    158
# mid-Feb      157
# mid-Apr      157
# early-Apr    155
# late-Aug     152
# early-Mar    151
# late-Jul     150
# mid-May      145
# late-Mar     145
# late-Apr     144
# early-Feb    140
# early-Jun    138
# late-May     135
# mid-Jan      131
# early-May    128
# early-Sep    128
# early-Jul    123
# early-Dec    123
# late-Nov     122
# late-Jan     119
# early-Jan     99
# late-Feb      95
# Name: release_category, dtype: int64

# %%
query = ''' SELECT release_category, AVG(profit) AS avg_profit, AVG(roi) AS avg_roi
            FROM movies
            GROUP BY release_category
            ;
            '''

psdf(query)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#
# InterfaceError: Error binding parameter 12 - probably unsupported type.
#
# The above exception was the direct cause of the following exception:
#
# ...
